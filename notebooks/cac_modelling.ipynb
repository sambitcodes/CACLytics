# %%
import pandas as pd
import category_encoders as ce
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
import seaborn as sns
import matplotlib as mlb
import matplotlib.image as mpimg
from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, KFold, RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor

import plotly.express as px
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import  metrics


from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from lightgbm import LGBMRegressor
from tpot import TPOTRegressor

import xgboost as xgb
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from IPython.display import display
import os
#plt.style.use("seaborn")
# %matplotlib inline  
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r'cac_dataset/customer_acquisition_costs.csv')

# %%
def preprocess_train(data):

    train_data = data.drop(["avg_cars_at home(approx).1"], axis=1)
    train_data["avg. yearly_income"] = train_data['avg. yearly_income'].str.replace(r'\$', '', regex=True) #cleaned yearly income
    def media_cleaner(value):
        if 'Daily' in value:
            value = "Daily Media"
        elif 'Sunday' in value:
            value = "Sunday Media"
        return value
    train_data["media_type"] = train_data["media_type"].apply(media_cleaner) #cleaned mediatype

    # Map the data value to strength score
    education_mapping = {
        "Partial High School": 1,
        "High School Degree": 2,
        "Partial College": 3,
        "Bachelors Degree": 4,
        "Graduate Degree": 5
    }

    houseowner_mapping = {"Y": 1, "N": 0}

    occupation_mapping = {'Manual' :1,
                        'Skilled Manual':2,
                        'Clerical':3,
                        'Professional':4,
                        'Management':5}

    member_card_mapping = {
        "Normal": 1,
        "Bronze": 2,
        "Silver": 3,
        "Golden": 4
    }
    income_mapping = {
        "10K - 30K": 1,
        "30K - 50K": 2,
        "50K - 70K": 3,
        "70K - 90K": 4,
        "90K - 110K": 5,
        "110K - 130K": 6,
        "130K - 150K": 7,
        "150K +": 8
    }
    car_mapping = {
        "0 car": 0.0,
        "1 car": 1.0,
        "2 car": 2.0,
        "3 car": 3.0,
        "4 car": 4.0
    }

    weights = {
        "education_encoded": 0.1,
        "houseowner_encoded": 0.15,
        "member_card_encoded": 0.2,
        "income_encoded": 0.3, 
        "occupation_encoded": 0.1,
        "cars_at_home" : 0.15
    }

    train_data["profile_strength"] = (
        (train_data["education"].map(education_mapping)) * weights["education_encoded"] +
        (train_data["houseowner"].map(houseowner_mapping)) * weights["houseowner_encoded"] +
        (train_data["member_card"].map(member_card_mapping)) * weights["member_card_encoded"] +
        (train_data["avg. yearly_income"].map(income_mapping)) * weights["income_encoded"] +
        (train_data["occupation"].map(occupation_mapping)) * weights["occupation_encoded"] +
        (train_data["avg_cars_at home(approx)"]) * weights["cars_at_home"] 
    ) 

    ordinal_cat = ["education","occupation","member_card","avg. yearly_income","store_type"]
    dic = {}
    for i in range(len(ordinal_cat)):
        dic[ordinal_cat[i]] = train_data[ordinal_cat[i]].unique()


    codes = [0,1,2,3,4,5,6,7]
    ed_map = pd.DataFrame({"education" : ["Partial High School","High School Degree","Partial College","Bachelors Degree","Graduate Degree"],
                        "encoding_values" : codes[:5]})
    mem_map = pd.DataFrame({"member_card":["Normal","Bronze","Silver","Golden"],
                            "encoding_values" : codes[:4]})
    occ_map = pd.DataFrame({"occupation" : ['Manual', 'Skilled Manual', 'Clerical', 'Professional', 'Management'],
                        "encoding_values" : codes[:5]})
    inc_map = pd.DataFrame({"avg. yearly_income" :['10K - 30K', '30K - 50K', '50K - 70K', '70K - 90K','90K - 110K', '110K - 130K', '130K - 150K', '150K +'],
                            "encoding_values" : codes})
    store_map = pd.DataFrame({"store_type":['Small Grocery', 'Mid-Size Grocery', 'Supermarket', 'Gourmet Supermarket', 'Deluxe Supermarket'],
                            "encoding_values" : codes[:5]})

    ordinal_order = [ed_map[ordinal_cat[0]],occ_map[ordinal_cat[1]],mem_map[ordinal_cat[2]],inc_map[ordinal_cat[3]],store_map[ordinal_cat[4]]]

    for i in range(len(ordinal_order)):
        train_data[ordinal_cat[i]] = pd.Categorical(train_data[ordinal_cat[i]], categories=ordinal_order[i], ordered=True).codes


    nominal_cat = train_data.select_dtypes('object').columns



    # Apply binary encoding
    binary_encoder = ce.BinaryEncoder(cols=nominal_cat)
    train_encoded = binary_encoder.fit_transform(train_data)

    def get_stats(data,col):
        data_column = data[col]
        op_mean = np.mean(data_column)
        op_median = np.median(data_column)
        op_std = np.std(data_column)
        op_var = np.var(data_column)
        op_min = np.min(data_column)
        op_max = np.max(data_column)
        op_1q = data_column.quantile(0.25)
        op_3q = data_column.quantile(0.75)
        op_iqr = op_3q - op_1q
        op_upper = min((op_3q + 1.5*(op_iqr)),data_column.max())
        op_lower = max((op_1q - 1.5*(op_iqr)),data_column.min())
        op_outliers = ((data_column < op_lower) | (data_column > op_upper)).sum()
        dic_stats = {"Mean": [op_mean],
                    "Median":[op_median],
                    "Standard-Deviation": [op_std],
                    "Variance": [op_var],
                    "Minimum Value": [op_min],
                    "Maximum Value": [op_max],
                    "Q1": [op_1q],
                    "Q3": [op_3q],
                    "IQR": [op_iqr],
                    "Upper Fence":[op_upper],
                    "Lower Fence": [op_lower],
                    "Outliers count":[op_outliers]}

        return dic_stats

    dic_sales = get_stats(train_encoded, "store_sales(in millions)") 
    train_encoded["store_sales(in millions)"] = np.where(train_encoded["store_sales(in millions)"] > dic_sales["Upper Fence"][0], dic_sales["Upper Fence"][0], (np.where(train_encoded["store_sales(in millions)"] < dic_sales["Lower Fence"][0], dic_sales["Lower Fence"][0], train_encoded["store_sales(in millions)"])))

    dic_cost = get_stats(train_encoded, "store_cost(in millions)") 
    train_encoded["store_cost(in millions)"] = np.where(train_encoded["store_cost(in millions)"] > dic_cost["Upper Fence"][0], dic_cost["Upper Fence"][0], (np.where(train_encoded["store_cost(in millions)"] < dic_cost["Lower Fence"][0], dic_cost["Lower Fence"][0], train_encoded["store_cost(in millions)"])))

    scaler = MinMaxScaler()
    preprocessed_data = pd.DataFrame(scaler.fit_transform(train_encoded), index=train_encoded.index, columns=train_encoded.columns)

    return preprocessed_data, binary_encoder, scaler

# %%
def preprocess_test(data, binary_encoder, scaler):

    train_data = data.drop(["avg_cars_at home(approx).1"], axis=1)
    train_data["avg. yearly_income"] = train_data['avg. yearly_income'].str.replace(r'\$', '', regex=True) #cleaned yearly income
    def media_cleaner(value):
        if 'Daily' in value:
            value = "Daily Media"
        elif 'Sunday' in value:
            value = "Sunday Media"
        return value
    train_data["media_type"] = train_data["media_type"].apply(media_cleaner) #cleaned mediatype

    # Map the data value to strength score
    education_mapping = {
        "Partial High School": 1,
        "High School Degree": 2,
        "Partial College": 3,
        "Bachelors Degree": 4,
        "Graduate Degree": 5
    }

    houseowner_mapping = {"Y": 1, "N": 0}

    occupation_mapping = {'Manual' :1,
                        'Skilled Manual':2,
                        'Clerical':3,
                        'Professional':4,
                        'Management':5}

    member_card_mapping = {
        "Normal": 1,
        "Bronze": 2,
        "Silver": 3,
        "Golden": 4
    }
    income_mapping = {
        "10K - 30K": 1,
        "30K - 50K": 2,
        "50K - 70K": 3,
        "70K - 90K": 4,
        "90K - 110K": 5,
        "110K - 130K": 6,
        "130K - 150K": 7,
        "150K +": 8
    }
    car_mapping = {
        "0 car": 0.0,
        "1 car": 1.0,
        "2 car": 2.0,
        "3 car": 3.0,
        "4 car": 4.0
    }

    weights = {
        "education_encoded": 0.1,
        "houseowner_encoded": 0.15,
        "member_card_encoded": 0.2,
        "income_encoded": 0.3, 
        "occupation_encoded": 0.1,
        "cars_at_home" : 0.15
    }

    train_data["profile_strength"] = (
        (train_data["education"].map(education_mapping)) * weights["education_encoded"] +
        (train_data["houseowner"].map(houseowner_mapping)) * weights["houseowner_encoded"] +
        (train_data["member_card"].map(member_card_mapping)) * weights["member_card_encoded"] +
        (train_data["avg. yearly_income"].map(income_mapping)) * weights["income_encoded"] +
        (train_data["occupation"].map(occupation_mapping)) * weights["occupation_encoded"] +
        (train_data["avg_cars_at home(approx)"]) * weights["cars_at_home"] 
    ) 

    ordinal_cat = ["education","occupation","member_card","avg. yearly_income","store_type"]
    dic = {}
    for i in range(len(ordinal_cat)):
        dic[ordinal_cat[i]] = train_data[ordinal_cat[i]].unique()


    codes = [0,1,2,3,4,5,6,7]
    ed_map = pd.DataFrame({"education" : ["Partial High School","High School Degree","Partial College","Bachelors Degree","Graduate Degree"],
                        "encoding_values" : codes[:5]})
    mem_map = pd.DataFrame({"member_card":["Normal","Bronze","Silver","Golden"],
                            "encoding_values" : codes[:4]})
    occ_map = pd.DataFrame({"occupation" : ['Manual', 'Skilled Manual', 'Clerical', 'Professional', 'Management'],
                        "encoding_values" : codes[:5]})
    inc_map = pd.DataFrame({"avg. yearly_income" :['10K - 30K', '30K - 50K', '50K - 70K', '70K - 90K','90K - 110K', '110K - 130K', '130K - 150K', '150K +'],
                            "encoding_values" : codes})
    store_map = pd.DataFrame({"store_type":['Small Grocery', 'Mid-Size Grocery', 'Supermarket', 'Gourmet Supermarket', 'Deluxe Supermarket'],
                            "encoding_values" : codes[:5]})

    ordinal_order = [ed_map[ordinal_cat[0]],occ_map[ordinal_cat[1]],mem_map[ordinal_cat[2]],inc_map[ordinal_cat[3]],store_map[ordinal_cat[4]]]

    for i in range(len(ordinal_order)):
        train_data[ordinal_cat[i]] = pd.Categorical(train_data[ordinal_cat[i]], categories=ordinal_order[i], ordered=True).codes


    nominal_cat = train_data.select_dtypes('object').columns



    # Apply binary encoding
    train_encoded = binary_encoder.transform(train_data)

    def get_stats(data,col):
        data_column = data[col]
        op_mean = np.mean(data_column)
        op_median = np.median(data_column)
        op_std = np.std(data_column)
        op_var = np.var(data_column)
        op_min = np.min(data_column)
        op_max = np.max(data_column)
        op_1q = data_column.quantile(0.25)
        op_3q = data_column.quantile(0.75)
        op_iqr = op_3q - op_1q
        op_upper = min((op_3q + 1.5*(op_iqr)),data_column.max())
        op_lower = max((op_1q - 1.5*(op_iqr)),data_column.min())
        op_outliers = ((data_column < op_lower) | (data_column > op_upper)).sum()
        dic_stats = {"Mean": [op_mean],
                    "Median":[op_median],
                    "Standard-Deviation": [op_std],
                    "Variance": [op_var],
                    "Minimum Value": [op_min],
                    "Maximum Value": [op_max],
                    "Q1": [op_1q],
                    "Q3": [op_3q],
                    "IQR": [op_iqr],
                    "Upper Fence":[op_upper],
                    "Lower Fence": [op_lower],
                    "Outliers count":[op_outliers]}

        return dic_stats

    dic_sales = get_stats(train_encoded, "store_sales(in millions)") 
    train_encoded["store_sales(in millions)"] = np.where(train_encoded["store_sales(in millions)"] > dic_sales["Upper Fence"][0], dic_sales["Upper Fence"][0], (np.where(train_encoded["store_sales(in millions)"] < dic_sales["Lower Fence"][0], dic_sales["Lower Fence"][0], train_encoded["store_sales(in millions)"])))

    dic_cost = get_stats(train_encoded, "store_cost(in millions)") 
    train_encoded["store_cost(in millions)"] = np.where(train_encoded["store_cost(in millions)"] > dic_cost["Upper Fence"][0], dic_cost["Upper Fence"][0], (np.where(train_encoded["store_cost(in millions)"] < dic_cost["Lower Fence"][0], dic_cost["Lower Fence"][0], train_encoded["store_cost(in millions)"])))

    preprocessed_data = pd.DataFrame(scaler.transform(train_encoded), index=train_encoded.index, columns=train_encoded.columns)

    return preprocessed_data

# %%
lr = LinearRegression()
svr = SVR()
dtr = DecisionTreeRegressor()
rfr = RandomForestRegressor()
mlpr = MLPRegressor()
lgbmr = LGBMRegressor()
gbr = GradientBoostingRegressor()
cbr = CatBoostRegressor()
model_list = [lr,svr,dtr,rfr,mlpr,gbr,cbr,lgbmr]
model_names = ["LinearRegression","SupportVectorRegressor","DecisionTreeRegressor","RandomForestRegressor",
                "MLPRegressor", "LGBMRegressor","GradientBoostingRegressor","CatBoostRegressor"]

# %%
def modelling(data, model):
    train, test = train_test_split(data, test_size=0.2, shuffle=True, random_state=42)
    X_train = train.drop("cost", axis=1)
    X_test = test.drop("cost", axis=1)
    y_train = train["cost"]
    y_test = test["cost"]
    X_train, binary_encoder, scaler = preprocess_train(X_train)
    X_test = preprocess_test(X_test, binary_encoder=binary_encoder, scaler=scaler)
    model.fit(X_train, y_train)
    predicted_values = model.predict(X_test)
    mse = mean_squared_error(y_test, predicted_values)
    mae = mean_absolute_error(y_test, predicted_values)
    r2_value = r2_score(y_test, predicted_values)
    adjusted_r2 = 1 - (1-r2_value)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

    print("model used : ",model)
    print("Mean Absolute Error : ", mae)
    print("Mean Squared Error : ", mse)
    print("R2 - score : ", r2_value)
    print("Adjusted R2 - score : ",adjusted_r2)
    return r2_value, adjusted_r2, mse, mae, model, X_train, X_test

# %%
r2_list = []
adjr2_list = []
mse_list = []
mae_list = []
trained_models = []
for model in model_list:
    model_r2,model_adjr2, mse, mae, trained_model, X_train_post, X_test_post = modelling(data, model)
    r2_list.append(model_r2)
    adjr2_list.append(model_adjr2)
    mse_list.append(mse)
    mae_list.append(mae)
    trained_models.append(trained_model)
# Out:
# model used :  LinearRegression()
# Mean Absolute Error :  24.216674010041782
# Mean Squared Error :  810.1593381992396
# R2 - score :  0.10333158308051293
# Adjusted R2 - score :  0.0978071918681207
# model used :  SVR()
# Mean Absolute Error :  17.62762777763817
# Mean Squared Error :  601.3803396625232
# R2 - score :  0.3344040712654416
# Adjusted R2 - score :  0.33030332205835167
# model used :  DecisionTreeRegressor()
# Mean Absolute Error :  0.07825004137037414
# Mean Squared Error :  2.6874100198576865
# R2 - score :  0.9970256274605493
# Adjusted R2 - score :  0.9970073022946249
# model used :  RandomForestRegressor()
# Mean Absolute Error :  0.1288801340395395
# Mean Squared Error :  1.699324987667551
# R2 - score :  0.9981192205351722
# Adjusted R2 - score :  0.9981076330170308
# model used :  MLPRegressor()
# Mean Absolute Error :  0.6831033463912701
# Mean Squared Error :  3.5785350633696558
# R2 - score :  0.9960393477938615
# Adjusted R2 - score :  0.9960149461401062
# model used :  GradientBoostingRegressor()
# Mean Absolute Error :  17.512286024910324
# Mean Squared Error :  460.47225916320974
# R2 - score :  0.4903583626191885
# Adjusted R2 - score :  0.4872184507745311
# Learning rate set to 0.075562
# 0:	learn: 29.3982333	total: 132ms	remaining: 2m 12s
# 1:	learn: 28.8180991	total: 145ms	remaining: 1m 12s
# 2:	learn: 28.2435069	total: 158ms	remaining: 52.6s
# 3:	learn: 27.6551724	total: 169ms	remaining: 42s
# 4:	learn: 27.1025649	total: 179ms	remaining: 35.6s
# 5:	learn: 26.5597093	total: 187ms	remaining: 31s
# 6:	learn: 26.0602163	total: 196ms	remaining: 27.8s
# 7:	learn: 25.5294004	total: 203ms	remaining: 25.1s
# 8:	learn: 25.1789714	total: 209ms	remaining: 23s
# 9:	learn: 24.7407569	total: 216ms	remaining: 21.4s
# 10:	learn: 24.3029971	total: 223ms	remaining: 20s
# 11:	learn: 23.8705539	total: 229ms	remaining: 18.8s
# 12:	learn: 23.5372469	total: 235ms	remaining: 17.8s
# 13:	learn: 23.1840326	total: 241ms	remaining: 17s
# 14:	learn: 22.8505783	total: 247ms	remaining: 16.2s
# 15:	learn: 22.5879211	total: 253ms	remaining: 15.6s
# 16:	learn: 22.3376631	total: 259ms	remaining: 15s
# 17:	learn: 22.0984313	total: 265ms	remaining: 14.4s
# 18:	learn: 21.7769435	total: 270ms	remaining: 14s
# 19:	learn: 21.4458108	total: 277ms	remaining: 13.6s
# 20:	learn: 21.1220910	total: 283ms	remaining: 13.2s
# 21:	learn: 20.8405443	total: 289ms	remaining: 12.8s
# 22:	learn: 20.6270471	total: 295ms	remaining: 12.5s
# 23:	learn: 20.3385115	total: 301ms	remaining: 12.3s
# 24:	learn: 20.1080403	total: 307ms	remaining: 12s
# 25:	learn: 19.9361654	total: 313ms	remaining: 11.7s
# 26:	learn: 19.6622757	total: 320ms	remaining: 11.5s
# 27:	learn: 19.4754605	total: 325ms	remaining: 11.3s
# 28:	learn: 19.2830854	total: 331ms	remaining: 11.1s
# 29:	learn: 19.0288421	total: 337ms	remaining: 10.9s
# 30:	learn: 18.8660917	total: 343ms	remaining: 10.7s
# 31:	learn: 18.6688951	total: 349ms	remaining: 10.6s
# 32:	learn: 18.3686524	total: 357ms	remaining: 10.4s
# 33:	learn: 18.1341382	total: 363ms	remaining: 10.3s
# 34:	learn: 17.9478152	total: 369ms	remaining: 10.2s
# 35:	learn: 17.6790391	total: 375ms	remaining: 10s
# 36:	learn: 17.3968908	total: 380ms	remaining: 9.9s
# 37:	learn: 17.1614326	total: 386ms	remaining: 9.77s
# 38:	learn: 17.0081465	total: 392ms	remaining: 9.65s
# 39:	learn: 16.8912808	total: 398ms	remaining: 9.56s
# 40:	learn: 16.6667365	total: 405ms	remaining: 9.47s
# 41:	learn: 16.4930373	total: 411ms	remaining: 9.38s
# 42:	learn: 16.3095069	total: 418ms	remaining: 9.3s
# 43:	learn: 16.0844717	total: 424ms	remaining: 9.22s
# 44:	learn: 15.9262306	total: 430ms	remaining: 9.13s
# 45:	learn: 15.7382491	total: 436ms	remaining: 9.05s
# 46:	learn: 15.5708566	total: 443ms	remaining: 8.97s
# 47:	learn: 15.3953285	total: 449ms	remaining: 8.9s
# 48:	learn: 15.2061621	total: 455ms	remaining: 8.83s
# 49:	learn: 15.0509486	total: 461ms	remaining: 8.75s
# 50:	learn: 14.8741652	total: 467ms	remaining: 8.68s
# 51:	learn: 14.6408010	total: 473ms	remaining: 8.62s
# 52:	learn: 14.4443006	total: 479ms	remaining: 8.56s
# 53:	learn: 14.3035516	total: 485ms	remaining: 8.5s
# 54:	learn: 14.1720832	total: 492ms	remaining: 8.45s
# 55:	learn: 14.0756076	total: 497ms	remaining: 8.39s
# 56:	learn: 13.9590242	total: 504ms	remaining: 8.33s
# 57:	learn: 13.8174532	total: 510ms	remaining: 8.28s
# 58:	learn: 13.7199163	total: 516ms	remaining: 8.22s
# 59:	learn: 13.5205589	total: 522ms	remaining: 8.19s
# 60:	learn: 13.4001168	total: 529ms	remaining: 8.14s
# 61:	learn: 13.2840538	total: 534ms	remaining: 8.08s
# 62:	learn: 13.1470834	total: 540ms	remaining: 8.03s
# 63:	learn: 13.0155984	total: 546ms	remaining: 7.99s
# 64:	learn: 12.8753656	total: 552ms	remaining: 7.94s
# 65:	learn: 12.7735253	total: 558ms	remaining: 7.9s
# 66:	learn: 12.6438283	total: 564ms	remaining: 7.86s
# 67:	learn: 12.5091220	total: 570ms	remaining: 7.82s
# 68:	learn: 12.4093730	total: 576ms	remaining: 7.78s
# 69:	learn: 12.2647091	total: 583ms	remaining: 7.74s
# 70:	learn: 12.1784914	total: 589ms	remaining: 7.71s
# 71:	learn: 12.1018234	total: 596ms	remaining: 7.68s
# 72:	learn: 12.0143356	total: 602ms	remaining: 7.64s
# 73:	learn: 11.9241080	total: 608ms	remaining: 7.61s
# 74:	learn: 11.8818036	total: 614ms	remaining: 7.57s
# 75:	learn: 11.7612930	total: 621ms	remaining: 7.55s
# 76:	learn: 11.6531611	total: 628ms	remaining: 7.52s
# 77:	learn: 11.5434426	total: 634ms	remaining: 7.49s
# 78:	learn: 11.4619339	total: 640ms	remaining: 7.46s
# 79:	learn: 11.3717596	total: 646ms	remaining: 7.43s
# 80:	learn: 11.2424312	total: 652ms	remaining: 7.4s
# 81:	learn: 11.1216060	total: 659ms	remaining: 7.37s
# 82:	learn: 10.9637892	total: 665ms	remaining: 7.34s
# 83:	learn: 10.8635570	total: 671ms	remaining: 7.32s
# 84:	learn: 10.7686299	total: 677ms	remaining: 7.29s
# 85:	learn: 10.6929441	total: 683ms	remaining: 7.26s
# 86:	learn: 10.6431459	total: 688ms	remaining: 7.22s
# 87:	learn: 10.5876277	total: 694ms	remaining: 7.2s
# 88:	learn: 10.4727422	total: 701ms	remaining: 7.17s
# 89:	learn: 10.3650970	total: 706ms	remaining: 7.14s
# 90:	learn: 10.2922343	total: 712ms	remaining: 7.11s
# 91:	learn: 10.1874703	total: 719ms	remaining: 7.09s
# 92:	learn: 10.0987156	total: 725ms	remaining: 7.07s
# 93:	learn: 9.9850217	total: 731ms	remaining: 7.05s
# 94:	learn: 9.9419553	total: 737ms	remaining: 7.02s
# 95:	learn: 9.8340212	total: 744ms	remaining: 7.01s
# 96:	learn: 9.7327691	total: 750ms	remaining: 6.98s
# 97:	learn: 9.6270593	total: 756ms	remaining: 6.96s
# 98:	learn: 9.5339951	total: 762ms	remaining: 6.93s
# 99:	learn: 9.4506352	total: 768ms	remaining: 6.91s
# 100:	learn: 9.3888095	total: 774ms	remaining: 6.89s
# 101:	learn: 9.2875449	total: 780ms	remaining: 6.87s
# 102:	learn: 9.1947618	total: 786ms	remaining: 6.85s
# 103:	learn: 9.1228023	total: 792ms	remaining: 6.83s
# 104:	learn: 9.0584661	total: 799ms	remaining: 6.81s
# 105:	learn: 9.0013910	total: 805ms	remaining: 6.79s
# 106:	learn: 8.9371928	total: 811ms	remaining: 6.77s
# 107:	learn: 8.8476097	total: 818ms	remaining: 6.75s
# 108:	learn: 8.7565457	total: 825ms	remaining: 6.74s
# 109:	learn: 8.6834550	total: 831ms	remaining: 6.72s
# 110:	learn: 8.5942267	total: 837ms	remaining: 6.7s
# 111:	learn: 8.5371624	total: 844ms	remaining: 6.69s
# 112:	learn: 8.4881357	total: 850ms	remaining: 6.67s
# 113:	learn: 8.4042589	total: 856ms	remaining: 6.65s
# 114:	learn: 8.3197339	total: 862ms	remaining: 6.64s
# 115:	learn: 8.2668316	total: 868ms	remaining: 6.62s
# 116:	learn: 8.1855195	total: 875ms	remaining: 6.6s
# 117:	learn: 8.1277186	total: 881ms	remaining: 6.58s
# 118:	learn: 8.0694434	total: 887ms	remaining: 6.57s
# 119:	learn: 8.0342331	total: 893ms	remaining: 6.55s
# 120:	learn: 7.9671455	total: 899ms	remaining: 6.53s
# 121:	learn: 7.8896389	total: 906ms	remaining: 6.52s
# 122:	learn: 7.8359780	total: 912ms	remaining: 6.5s
# 123:	learn: 7.7669444	total: 918ms	remaining: 6.48s
# 124:	learn: 7.7079440	total: 924ms	remaining: 6.47s
# 125:	learn: 7.6758937	total: 931ms	remaining: 6.46s
# 126:	learn: 7.6232017	total: 937ms	remaining: 6.44s
# 127:	learn: 7.6051010	total: 943ms	remaining: 6.42s
# 128:	learn: 7.5484717	total: 950ms	remaining: 6.41s
# 129:	learn: 7.5042314	total: 956ms	remaining: 6.4s
# 130:	learn: 7.4568335	total: 963ms	remaining: 6.38s
# 131:	learn: 7.4087358	total: 970ms	remaining: 6.38s
# 132:	learn: 7.3657699	total: 976ms	remaining: 6.36s
# 133:	learn: 7.2982557	total: 983ms	remaining: 6.35s
# 134:	learn: 7.2381825	total: 989ms	remaining: 6.34s
# 135:	learn: 7.1952061	total: 996ms	remaining: 6.33s
# 136:	learn: 7.1302053	total: 1s	remaining: 6.32s
# 137:	learn: 7.0820926	total: 1.01s	remaining: 6.31s
# 138:	learn: 7.0276765	total: 1.02s	remaining: 6.3s
# 139:	learn: 6.9773592	total: 1.02s	remaining: 6.29s
# 140:	learn: 6.9196735	total: 1.03s	remaining: 6.28s
# 141:	learn: 6.8739734	total: 1.04s	remaining: 6.27s
# 142:	learn: 6.8346351	total: 1.04s	remaining: 6.25s
# 143:	learn: 6.7735384	total: 1.05s	remaining: 6.24s
# 144:	learn: 6.7282798	total: 1.06s	remaining: 6.23s
# 145:	learn: 6.6884655	total: 1.06s	remaining: 6.21s
# 146:	learn: 6.6531827	total: 1.07s	remaining: 6.2s
# 147:	learn: 6.6177256	total: 1.07s	remaining: 6.19s
# 148:	learn: 6.5563808	total: 1.08s	remaining: 6.17s
# 149:	learn: 6.5239879	total: 1.09s	remaining: 6.16s
# 150:	learn: 6.4918745	total: 1.09s	remaining: 6.15s
# 151:	learn: 6.4311482	total: 1.1s	remaining: 6.13s
# 152:	learn: 6.4139820	total: 1.1s	remaining: 6.12s
# 153:	learn: 6.3736626	total: 1.11s	remaining: 6.11s
# 154:	learn: 6.3366842	total: 1.12s	remaining: 6.09s
# 155:	learn: 6.3047408	total: 1.12s	remaining: 6.08s
# 156:	learn: 6.2683428	total: 1.13s	remaining: 6.07s
# 157:	learn: 6.2274317	total: 1.14s	remaining: 6.06s
# 158:	learn: 6.1787018	total: 1.15s	remaining: 6.06s
# 159:	learn: 6.1436504	total: 1.15s	remaining: 6.04s
# 160:	learn: 6.1243786	total: 1.16s	remaining: 6.03s
# 161:	learn: 6.0936853	total: 1.16s	remaining: 6.02s
# 162:	learn: 6.0380962	total: 1.17s	remaining: 6s
# 163:	learn: 5.9858114	total: 1.18s	remaining: 5.99s
# 164:	learn: 5.9138631	total: 1.18s	remaining: 5.98s
# 165:	learn: 5.8835058	total: 1.19s	remaining: 5.96s
# 166:	learn: 5.8583775	total: 1.19s	remaining: 5.95s
# 167:	learn: 5.8154147	total: 1.2s	remaining: 5.94s
# 168:	learn: 5.7840696	total: 1.21s	remaining: 5.93s
# 169:	learn: 5.7467714	total: 1.21s	remaining: 5.92s
# 170:	learn: 5.6998875	total: 1.22s	remaining: 5.92s
# 171:	learn: 5.6718048	total: 1.23s	remaining: 5.91s
# 172:	learn: 5.6292368	total: 1.23s	remaining: 5.89s
# 173:	learn: 5.5847551	total: 1.24s	remaining: 5.88s
# 174:	learn: 5.5413150	total: 1.25s	remaining: 5.87s
# 175:	learn: 5.5179889	total: 1.25s	remaining: 5.86s
# 176:	learn: 5.4950676	total: 1.26s	remaining: 5.84s
# 177:	learn: 5.4725269	total: 1.26s	remaining: 5.83s
# 178:	learn: 5.4393927	total: 1.27s	remaining: 5.82s
# 179:	learn: 5.4183361	total: 1.27s	remaining: 5.81s
# 180:	learn: 5.3882840	total: 1.28s	remaining: 5.8s
# 181:	learn: 5.3614494	total: 1.29s	remaining: 5.79s
# 182:	learn: 5.3264769	total: 1.29s	remaining: 5.77s
# 183:	learn: 5.2826064	total: 1.3s	remaining: 5.76s
# 184:	learn: 5.2579628	total: 1.3s	remaining: 5.75s
# 185:	learn: 5.2354766	total: 1.31s	remaining: 5.74s
# 186:	learn: 5.2037507	total: 1.32s	remaining: 5.73s
# 187:	learn: 5.1526373	total: 1.32s	remaining: 5.72s
# 188:	learn: 5.1145071	total: 1.33s	remaining: 5.7s
# 189:	learn: 5.0728889	total: 1.33s	remaining: 5.69s
# 190:	learn: 5.0550602	total: 1.34s	remaining: 5.68s
# 191:	learn: 5.0240701	total: 1.35s	remaining: 5.67s
# 192:	learn: 5.0068683	total: 1.35s	remaining: 5.66s
# 193:	learn: 4.9629511	total: 1.36s	remaining: 5.65s
# 194:	learn: 4.9356223	total: 1.36s	remaining: 5.64s
# 195:	learn: 4.9095584	total: 1.37s	remaining: 5.63s
# 196:	learn: 4.8839505	total: 1.38s	remaining: 5.62s
# 197:	learn: 4.8558564	total: 1.38s	remaining: 5.61s
# 198:	learn: 4.8264521	total: 1.39s	remaining: 5.59s
# 199:	learn: 4.7926508	total: 1.4s	remaining: 5.58s
# 200:	learn: 4.7673308	total: 1.4s	remaining: 5.57s
# 201:	learn: 4.7184339	total: 1.41s	remaining: 5.56s
# 202:	learn: 4.6894349	total: 1.41s	remaining: 5.55s
# 203:	learn: 4.6645530	total: 1.42s	remaining: 5.54s
# 204:	learn: 4.6481616	total: 1.43s	remaining: 5.53s
# 205:	learn: 4.6393817	total: 1.43s	remaining: 5.52s
# 206:	learn: 4.6126025	total: 1.44s	remaining: 5.52s
# 207:	learn: 4.5897736	total: 1.45s	remaining: 5.51s
# 208:	learn: 4.5551854	total: 1.45s	remaining: 5.49s
# 209:	learn: 4.5470714	total: 1.46s	remaining: 5.48s
# 210:	learn: 4.5213080	total: 1.46s	remaining: 5.47s
# 211:	learn: 4.5066765	total: 1.47s	remaining: 5.46s
# 212:	learn: 4.4757505	total: 1.48s	remaining: 5.45s
# 213:	learn: 4.4649000	total: 1.48s	remaining: 5.44s
# 214:	learn: 4.4590529	total: 1.49s	remaining: 5.43s
# 215:	learn: 4.4464566	total: 1.49s	remaining: 5.42s
# 216:	learn: 4.4242500	total: 1.5s	remaining: 5.41s
# 217:	learn: 4.4024160	total: 1.51s	remaining: 5.4s
# 218:	learn: 4.3786165	total: 1.51s	remaining: 5.39s
# 219:	learn: 4.3594460	total: 1.52s	remaining: 5.38s
# 220:	learn: 4.3185655	total: 1.52s	remaining: 5.37s
# 221:	learn: 4.2879814	total: 1.53s	remaining: 5.36s
# 222:	learn: 4.2793526	total: 1.54s	remaining: 5.36s
# 223:	learn: 4.2433213	total: 1.54s	remaining: 5.35s
# 224:	learn: 4.2254587	total: 1.55s	remaining: 5.34s
# 225:	learn: 4.2043902	total: 1.56s	remaining: 5.33s
# 226:	learn: 4.1830657	total: 1.56s	remaining: 5.32s
# 227:	learn: 4.1647530	total: 1.57s	remaining: 5.31s
# 228:	learn: 4.1364521	total: 1.57s	remaining: 5.3s
# 229:	learn: 4.1200504	total: 1.58s	remaining: 5.29s
# 230:	learn: 4.1088546	total: 1.59s	remaining: 5.28s
# 231:	learn: 4.1011152	total: 1.59s	remaining: 5.27s
# 232:	learn: 4.0635784	total: 1.6s	remaining: 5.26s
# 233:	learn: 4.0456463	total: 1.6s	remaining: 5.25s
# 234:	learn: 4.0191290	total: 1.61s	remaining: 5.25s
# 235:	learn: 4.0026144	total: 1.62s	remaining: 5.24s
# 236:	learn: 3.9888801	total: 1.62s	remaining: 5.23s
# 237:	learn: 3.9741292	total: 1.63s	remaining: 5.22s
# 238:	learn: 3.9496708	total: 1.64s	remaining: 5.21s
# 239:	learn: 3.9161415	total: 1.64s	remaining: 5.2s
# 240:	learn: 3.8950405	total: 1.65s	remaining: 5.2s
# 241:	learn: 3.8753489	total: 1.66s	remaining: 5.19s
# 242:	learn: 3.8621222	total: 1.66s	remaining: 5.18s
# 243:	learn: 3.8414168	total: 1.67s	remaining: 5.17s
# 244:	learn: 3.8189568	total: 1.68s	remaining: 5.16s
# 245:	learn: 3.8033922	total: 1.68s	remaining: 5.15s
# 246:	learn: 3.7855032	total: 1.69s	remaining: 5.14s
# 247:	learn: 3.7630016	total: 1.69s	remaining: 5.13s
# 248:	learn: 3.7497327	total: 1.7s	remaining: 5.12s
# 249:	learn: 3.7276383	total: 1.7s	remaining: 5.11s
# 250:	learn: 3.7105726	total: 1.71s	remaining: 5.1s
# 251:	learn: 3.7056876	total: 1.72s	remaining: 5.09s
# 252:	learn: 3.6870561	total: 1.72s	remaining: 5.09s
# 253:	learn: 3.6750738	total: 1.73s	remaining: 5.08s
# 254:	learn: 3.6534468	total: 1.74s	remaining: 5.07s
# 255:	learn: 3.6374957	total: 1.74s	remaining: 5.06s
# 256:	learn: 3.6242749	total: 1.75s	remaining: 5.05s
# 257:	learn: 3.6197117	total: 1.75s	remaining: 5.04s
# 258:	learn: 3.6115258	total: 1.76s	remaining: 5.03s
# 259:	learn: 3.5971298	total: 1.76s	remaining: 5.02s
# 260:	learn: 3.5819072	total: 1.77s	remaining: 5.01s
# 261:	learn: 3.5769022	total: 1.78s	remaining: 5s
# 262:	learn: 3.5514590	total: 1.78s	remaining: 5s
# 263:	learn: 3.5441466	total: 1.79s	remaining: 4.99s
# 264:	learn: 3.5329177	total: 1.79s	remaining: 4.98s
# 265:	learn: 3.5075794	total: 1.8s	remaining: 4.97s
# 266:	learn: 3.5047546	total: 1.81s	remaining: 4.96s
# 267:	learn: 3.5010923	total: 1.81s	remaining: 4.95s
# 268:	learn: 3.4897668	total: 1.82s	remaining: 4.95s
# 269:	learn: 3.4860964	total: 1.82s	remaining: 4.94s
# 270:	learn: 3.4816338	total: 1.83s	remaining: 4.93s
# 271:	learn: 3.4788866	total: 1.84s	remaining: 4.92s
# 272:	learn: 3.4699257	total: 1.84s	remaining: 4.91s
# 273:	learn: 3.4639386	total: 1.85s	remaining: 4.91s
# 274:	learn: 3.4525823	total: 1.86s	remaining: 4.9s
# 275:	learn: 3.4417598	total: 1.86s	remaining: 4.89s
# 276:	learn: 3.4380055	total: 1.87s	remaining: 4.88s
# 277:	learn: 3.4160717	total: 1.88s	remaining: 4.87s
# 278:	learn: 3.4125080	total: 1.88s	remaining: 4.86s
# 279:	learn: 3.3960739	total: 1.89s	remaining: 4.85s
# 280:	learn: 3.3853686	total: 1.89s	remaining: 4.84s
# 281:	learn: 3.3774690	total: 1.9s	remaining: 4.83s
# 282:	learn: 3.3692685	total: 1.9s	remaining: 4.83s
# 283:	learn: 3.3621979	total: 1.91s	remaining: 4.82s
# 284:	learn: 3.3470954	total: 1.92s	remaining: 4.81s
# 285:	learn: 3.3377760	total: 1.92s	remaining: 4.8s
# 286:	learn: 3.3332381	total: 1.93s	remaining: 4.79s
# 287:	learn: 3.3298993	total: 1.94s	remaining: 4.78s
# 288:	learn: 3.3190046	total: 1.94s	remaining: 4.78s
# 289:	learn: 3.3152160	total: 1.95s	remaining: 4.77s
# 290:	learn: 3.3087803	total: 1.95s	remaining: 4.76s
# 291:	learn: 3.3041420	total: 1.96s	remaining: 4.75s
# 292:	learn: 3.2993165	total: 1.96s	remaining: 4.74s
# 293:	learn: 3.2972849	total: 1.97s	remaining: 4.73s
# 294:	learn: 3.2946903	total: 1.98s	remaining: 4.72s
# 295:	learn: 3.2871031	total: 1.98s	remaining: 4.71s
# 296:	learn: 3.2841897	total: 1.99s	remaining: 4.71s
# 297:	learn: 3.2786389	total: 2s	remaining: 4.7s
# 298:	learn: 3.2710985	total: 2s	remaining: 4.69s
# 299:	learn: 3.2692919	total: 2.01s	remaining: 4.68s
# 300:	learn: 3.2672230	total: 2.02s	remaining: 4.68s
# 301:	learn: 3.2616112	total: 2.02s	remaining: 4.67s
# 302:	learn: 3.2576914	total: 2.03s	remaining: 4.66s
# 303:	learn: 3.2492182	total: 2.03s	remaining: 4.66s
# 304:	learn: 3.2458642	total: 2.04s	remaining: 4.65s
# 305:	learn: 3.2391006	total: 2.05s	remaining: 4.64s
# 306:	learn: 3.2233240	total: 2.05s	remaining: 4.64s
# 307:	learn: 3.2213943	total: 2.06s	remaining: 4.63s
# 308:	learn: 3.2095208	total: 2.07s	remaining: 4.62s
# 309:	learn: 3.1902270	total: 2.07s	remaining: 4.61s
# 310:	learn: 3.1743191	total: 2.08s	remaining: 4.61s
# 311:	learn: 3.1714108	total: 2.08s	remaining: 4.6s
# 312:	learn: 3.1548929	total: 2.09s	remaining: 4.59s
# 313:	learn: 3.1471107	total: 2.1s	remaining: 4.58s
# 314:	learn: 3.1377685	total: 2.1s	remaining: 4.57s
# 315:	learn: 3.1285058	total: 2.11s	remaining: 4.56s
# 316:	learn: 3.1170423	total: 2.11s	remaining: 4.55s
# 317:	learn: 3.1089051	total: 2.12s	remaining: 4.55s
# 318:	learn: 3.0967773	total: 2.13s	remaining: 4.54s
# 319:	learn: 3.0915620	total: 2.13s	remaining: 4.53s
# 320:	learn: 3.0870913	total: 2.14s	remaining: 4.53s
# 321:	learn: 3.0775814	total: 2.15s	remaining: 4.52s
# 322:	learn: 3.0680796	total: 2.15s	remaining: 4.51s
# 323:	learn: 3.0606148	total: 2.16s	remaining: 4.5s
# 324:	learn: 3.0525857	total: 2.16s	remaining: 4.49s
# 325:	learn: 3.0512058	total: 2.17s	remaining: 4.48s
# 326:	learn: 3.0399633	total: 2.17s	remaining: 4.48s
# 327:	learn: 3.0355716	total: 2.18s	remaining: 4.47s
# 328:	learn: 3.0304178	total: 2.19s	remaining: 4.46s
# 329:	learn: 3.0154117	total: 2.19s	remaining: 4.45s
# 330:	learn: 3.0069236	total: 2.2s	remaining: 4.44s
# 331:	learn: 2.9960115	total: 2.2s	remaining: 4.44s
# 332:	learn: 2.9764542	total: 2.21s	remaining: 4.43s
# 333:	learn: 2.9605154	total: 2.22s	remaining: 4.42s
# 334:	learn: 2.9537020	total: 2.22s	remaining: 4.41s
# 335:	learn: 2.9335164	total: 2.23s	remaining: 4.41s
# 336:	learn: 2.9243594	total: 2.24s	remaining: 4.4s
# 337:	learn: 2.9230134	total: 2.24s	remaining: 4.39s
# 338:	learn: 2.9215008	total: 2.25s	remaining: 4.38s
# 339:	learn: 2.9155055	total: 2.26s	remaining: 4.39s
# 340:	learn: 2.9075579	total: 2.27s	remaining: 4.39s
# 341:	learn: 2.9064310	total: 2.28s	remaining: 4.38s
# 342:	learn: 2.8924386	total: 2.28s	remaining: 4.37s
# 343:	learn: 2.8852642	total: 2.29s	remaining: 4.36s
# 344:	learn: 2.8847758	total: 2.29s	remaining: 4.36s
# 345:	learn: 2.8837448	total: 2.3s	remaining: 4.35s
# 346:	learn: 2.8774286	total: 2.31s	remaining: 4.34s
# 347:	learn: 2.8731184	total: 2.31s	remaining: 4.33s
# 348:	learn: 2.8711097	total: 2.32s	remaining: 4.32s
# 349:	learn: 2.8686390	total: 2.32s	remaining: 4.31s
# 350:	learn: 2.8658948	total: 2.33s	remaining: 4.31s
# 351:	learn: 2.8552795	total: 2.33s	remaining: 4.3s
# 352:	learn: 2.8481112	total: 2.34s	remaining: 4.29s
# 353:	learn: 2.8417328	total: 2.35s	remaining: 4.28s
# 354:	learn: 2.8408388	total: 2.35s	remaining: 4.27s
# 355:	learn: 2.8389270	total: 2.36s	remaining: 4.26s
# 356:	learn: 2.8324333	total: 2.36s	remaining: 4.26s
# 357:	learn: 2.8263234	total: 2.37s	remaining: 4.25s
# 358:	learn: 2.8240916	total: 2.38s	remaining: 4.24s
# 359:	learn: 2.8182183	total: 2.38s	remaining: 4.23s
# 360:	learn: 2.8167989	total: 2.39s	remaining: 4.22s
# 361:	learn: 2.8160589	total: 2.39s	remaining: 4.22s
# 362:	learn: 2.8048394	total: 2.4s	remaining: 4.21s
# 363:	learn: 2.7974994	total: 2.4s	remaining: 4.2s
# 364:	learn: 2.7877025	total: 2.41s	remaining: 4.2s
# 365:	learn: 2.7812606	total: 2.42s	remaining: 4.19s
# 366:	learn: 2.7760009	total: 2.42s	remaining: 4.18s
# 367:	learn: 2.7685034	total: 2.43s	remaining: 4.17s
# 368:	learn: 2.7533432	total: 2.44s	remaining: 4.17s
# 369:	learn: 2.7403394	total: 2.44s	remaining: 4.16s
# 370:	learn: 2.7367597	total: 2.45s	remaining: 4.15s
# 371:	learn: 2.7311555	total: 2.46s	remaining: 4.15s
# 372:	learn: 2.7210466	total: 2.46s	remaining: 4.14s
# 373:	learn: 2.7066699	total: 2.47s	remaining: 4.13s
# 374:	learn: 2.6954257	total: 2.47s	remaining: 4.12s
# 375:	learn: 2.6868928	total: 2.48s	remaining: 4.12s
# 376:	learn: 2.6838522	total: 2.49s	remaining: 4.11s
# 377:	learn: 2.6756595	total: 2.49s	remaining: 4.1s
# 378:	learn: 2.6695274	total: 2.5s	remaining: 4.09s
# 379:	learn: 2.6661955	total: 2.5s	remaining: 4.09s
# 380:	learn: 2.6633903	total: 2.51s	remaining: 4.08s
# 381:	learn: 2.6613883	total: 2.52s	remaining: 4.07s
# 382:	learn: 2.6534943	total: 2.52s	remaining: 4.06s
# 383:	learn: 2.6522405	total: 2.53s	remaining: 4.06s
# 384:	learn: 2.6513623	total: 2.53s	remaining: 4.05s
# 385:	learn: 2.6506895	total: 2.54s	remaining: 4.04s
# 386:	learn: 2.6495970	total: 2.54s	remaining: 4.03s
# 387:	learn: 2.6417290	total: 2.55s	remaining: 4.02s
# 388:	learn: 2.6394216	total: 2.56s	remaining: 4.02s
# 389:	learn: 2.6371179	total: 2.56s	remaining: 4.01s
# 390:	learn: 2.6259170	total: 2.57s	remaining: 4s
# 391:	learn: 2.6153677	total: 2.58s	remaining: 3.99s
# 392:	learn: 2.6043107	total: 2.58s	remaining: 3.99s
# 393:	learn: 2.5974834	total: 2.59s	remaining: 3.98s
# 394:	learn: 2.5929798	total: 2.59s	remaining: 3.97s
# 395:	learn: 2.5913523	total: 2.6s	remaining: 3.96s
# 396:	learn: 2.5901514	total: 2.6s	remaining: 3.96s
# 397:	learn: 2.5887946	total: 2.63s	remaining: 3.98s
# 398:	learn: 2.5864303	total: 2.65s	remaining: 3.99s
# 399:	learn: 2.5834703	total: 2.66s	remaining: 3.99s
# 400:	learn: 2.5788669	total: 2.67s	remaining: 3.98s
# 401:	learn: 2.5770810	total: 2.67s	remaining: 3.98s
# 402:	learn: 2.5748732	total: 2.68s	remaining: 3.97s
# 403:	learn: 2.5738366	total: 2.68s	remaining: 3.96s
# 404:	learn: 2.5733531	total: 2.69s	remaining: 3.95s
# 405:	learn: 2.5608976	total: 2.7s	remaining: 3.94s
# 406:	learn: 2.5474687	total: 2.7s	remaining: 3.94s
# 407:	learn: 2.5420381	total: 2.71s	remaining: 3.93s
# 408:	learn: 2.5329115	total: 2.71s	remaining: 3.92s
# 409:	learn: 2.5203251	total: 2.72s	remaining: 3.91s
# 410:	learn: 2.5196675	total: 2.73s	remaining: 3.91s
# 411:	learn: 2.5123827	total: 2.73s	remaining: 3.9s
# 412:	learn: 2.5022015	total: 2.74s	remaining: 3.89s
# 413:	learn: 2.4950930	total: 2.74s	remaining: 3.88s
# 414:	learn: 2.4845602	total: 2.75s	remaining: 3.88s
# 415:	learn: 2.4794568	total: 2.76s	remaining: 3.87s
# 416:	learn: 2.4708179	total: 2.76s	remaining: 3.86s
# 417:	learn: 2.4642112	total: 2.77s	remaining: 3.85s
# 418:	learn: 2.4575768	total: 2.77s	remaining: 3.85s
# 419:	learn: 2.4468733	total: 2.78s	remaining: 3.84s
# 420:	learn: 2.4404102	total: 2.79s	remaining: 3.83s
# 421:	learn: 2.4332310	total: 2.79s	remaining: 3.83s
# 422:	learn: 2.4220624	total: 2.8s	remaining: 3.82s
# 423:	learn: 2.4145614	total: 2.81s	remaining: 3.81s
# 424:	learn: 2.4051162	total: 2.81s	remaining: 3.81s
# 425:	learn: 2.4010489	total: 2.82s	remaining: 3.8s
# 426:	learn: 2.3939146	total: 2.83s	remaining: 3.79s
# 427:	learn: 2.3885514	total: 2.83s	remaining: 3.79s
# 428:	learn: 2.3787151	total: 2.84s	remaining: 3.78s
# 429:	learn: 2.3727144	total: 2.85s	remaining: 3.77s
# 430:	learn: 2.3622961	total: 2.85s	remaining: 3.76s
# 431:	learn: 2.3591737	total: 2.86s	remaining: 3.76s
# 432:	learn: 2.3538303	total: 2.86s	remaining: 3.75s
# 433:	learn: 2.3505960	total: 2.87s	remaining: 3.74s
# 434:	learn: 2.3483130	total: 2.88s	remaining: 3.74s
# 435:	learn: 2.3470415	total: 2.88s	remaining: 3.73s
# 436:	learn: 2.3408909	total: 2.89s	remaining: 3.72s
# 437:	learn: 2.3340352	total: 2.9s	remaining: 3.71s
# 438:	learn: 2.3311875	total: 2.9s	remaining: 3.71s
# 439:	learn: 2.3223440	total: 2.91s	remaining: 3.7s
# 440:	learn: 2.3145684	total: 2.91s	remaining: 3.69s
# 441:	learn: 2.3070045	total: 2.92s	remaining: 3.69s
# 442:	learn: 2.3040439	total: 2.92s	remaining: 3.68s
# 443:	learn: 2.3026295	total: 2.93s	remaining: 3.67s
# 444:	learn: 2.3007350	total: 2.94s	remaining: 3.66s
# 445:	learn: 2.2989143	total: 2.94s	remaining: 3.65s
# 446:	learn: 2.2919057	total: 2.95s	remaining: 3.65s
# 447:	learn: 2.2905561	total: 2.96s	remaining: 3.65s
# 448:	learn: 2.2867250	total: 2.96s	remaining: 3.64s
# 449:	learn: 2.2847695	total: 2.97s	remaining: 3.63s
# 450:	learn: 2.2826112	total: 2.98s	remaining: 3.62s
# 451:	learn: 2.2814832	total: 2.98s	remaining: 3.62s
# 452:	learn: 2.2781157	total: 2.99s	remaining: 3.61s
# 453:	learn: 2.2768419	total: 3s	remaining: 3.6s
# 454:	learn: 2.2708282	total: 3s	remaining: 3.6s
# 455:	learn: 2.2665549	total: 3.01s	remaining: 3.59s
# 456:	learn: 2.2610845	total: 3.01s	remaining: 3.58s
# 457:	learn: 2.2562687	total: 3.02s	remaining: 3.58s
# 458:	learn: 2.2553233	total: 3.03s	remaining: 3.57s
# 459:	learn: 2.2517788	total: 3.03s	remaining: 3.56s
# 460:	learn: 2.2488969	total: 3.04s	remaining: 3.55s
# 461:	learn: 2.2464067	total: 3.05s	remaining: 3.55s
# 462:	learn: 2.2440963	total: 3.05s	remaining: 3.54s
# 463:	learn: 2.2388705	total: 3.06s	remaining: 3.53s
# 464:	learn: 2.2339603	total: 3.06s	remaining: 3.53s
# 465:	learn: 2.2333187	total: 3.07s	remaining: 3.52s
# 466:	learn: 2.2290400	total: 3.08s	remaining: 3.51s
# 467:	learn: 2.2286137	total: 3.08s	remaining: 3.51s
# 468:	learn: 2.2247959	total: 3.09s	remaining: 3.5s
# 469:	learn: 2.2226064	total: 3.1s	remaining: 3.49s
# 470:	learn: 2.2217947	total: 3.1s	remaining: 3.49s
# 471:	learn: 2.2212004	total: 3.11s	remaining: 3.48s
# 472:	learn: 2.2171170	total: 3.12s	remaining: 3.47s
# 473:	learn: 2.2159425	total: 3.12s	remaining: 3.47s
# 474:	learn: 2.2142707	total: 3.13s	remaining: 3.46s
# 475:	learn: 2.2103211	total: 3.14s	remaining: 3.45s
# 476:	learn: 2.2065679	total: 3.14s	remaining: 3.45s
# 477:	learn: 2.2035914	total: 3.15s	remaining: 3.44s
# 478:	learn: 2.1966242	total: 3.16s	remaining: 3.43s
# 479:	learn: 2.1897307	total: 3.16s	remaining: 3.43s
# 480:	learn: 2.1830204	total: 3.17s	remaining: 3.42s
# 481:	learn: 2.1804581	total: 3.18s	remaining: 3.41s
# 482:	learn: 2.1745601	total: 3.18s	remaining: 3.41s
# 483:	learn: 2.1712689	total: 3.19s	remaining: 3.4s
# 484:	learn: 2.1709460	total: 3.19s	remaining: 3.39s
# 485:	learn: 2.1636352	total: 3.2s	remaining: 3.38s
# 486:	learn: 2.1579180	total: 3.21s	remaining: 3.38s
# 487:	learn: 2.1534550	total: 3.21s	remaining: 3.37s
# 488:	learn: 2.1514007	total: 3.22s	remaining: 3.36s
# 489:	learn: 2.1489023	total: 3.23s	remaining: 3.36s
# 490:	learn: 2.1481835	total: 3.23s	remaining: 3.35s
# 491:	learn: 2.1471214	total: 3.24s	remaining: 3.34s
# 492:	learn: 2.1420015	total: 3.24s	remaining: 3.34s
# 493:	learn: 2.1392236	total: 3.25s	remaining: 3.33s
# 494:	learn: 2.1376934	total: 3.26s	remaining: 3.32s
# 495:	learn: 2.1369627	total: 3.26s	remaining: 3.31s
# 496:	learn: 2.1367033	total: 3.27s	remaining: 3.31s
# 497:	learn: 2.1347391	total: 3.28s	remaining: 3.3s
# 498:	learn: 2.1333073	total: 3.28s	remaining: 3.29s
# 499:	learn: 2.1298585	total: 3.29s	remaining: 3.29s
# 500:	learn: 2.1289523	total: 3.29s	remaining: 3.28s
# 501:	learn: 2.1277941	total: 3.3s	remaining: 3.27s
# 502:	learn: 2.1271244	total: 3.3s	remaining: 3.27s
# 503:	learn: 2.1239657	total: 3.31s	remaining: 3.26s
# 504:	learn: 2.1209351	total: 3.32s	remaining: 3.25s
# 505:	learn: 2.1187593	total: 3.32s	remaining: 3.24s
# 506:	learn: 2.1170459	total: 3.33s	remaining: 3.23s
# 507:	learn: 2.1158351	total: 3.33s	remaining: 3.23s
# 508:	learn: 2.1139650	total: 3.34s	remaining: 3.22s
# 509:	learn: 2.1106720	total: 3.35s	remaining: 3.21s
# 510:	learn: 2.1098341	total: 3.35s	remaining: 3.21s
# 511:	learn: 2.1093903	total: 3.36s	remaining: 3.2s
# 512:	learn: 2.1090164	total: 3.36s	remaining: 3.19s
# 513:	learn: 2.1072145	total: 3.37s	remaining: 3.19s
# 514:	learn: 2.1045672	total: 3.38s	remaining: 3.18s
# 515:	learn: 2.0991001	total: 3.38s	remaining: 3.17s
# 516:	learn: 2.0932474	total: 3.39s	remaining: 3.17s
# 517:	learn: 2.0905351	total: 3.39s	remaining: 3.16s
# 518:	learn: 2.0864658	total: 3.4s	remaining: 3.15s
# 519:	learn: 2.0844629	total: 3.4s	remaining: 3.14s
# 520:	learn: 2.0809974	total: 3.41s	remaining: 3.14s
# 521:	learn: 2.0776910	total: 3.42s	remaining: 3.13s
# 522:	learn: 2.0721846	total: 3.42s	remaining: 3.12s
# 523:	learn: 2.0668084	total: 3.43s	remaining: 3.12s
# 524:	learn: 2.0649299	total: 3.44s	remaining: 3.11s
# 525:	learn: 2.0621023	total: 3.44s	remaining: 3.1s
# 526:	learn: 2.0574648	total: 3.45s	remaining: 3.09s
# 527:	learn: 2.0544930	total: 3.45s	remaining: 3.09s
# 528:	learn: 2.0533039	total: 3.46s	remaining: 3.08s
# 529:	learn: 2.0473298	total: 3.47s	remaining: 3.07s
# 530:	learn: 2.0436385	total: 3.47s	remaining: 3.07s
# 531:	learn: 2.0393441	total: 3.48s	remaining: 3.06s
# 532:	learn: 2.0354420	total: 3.49s	remaining: 3.06s
# 533:	learn: 2.0298012	total: 3.49s	remaining: 3.05s
# 534:	learn: 2.0271298	total: 3.5s	remaining: 3.04s
# 535:	learn: 2.0243719	total: 3.5s	remaining: 3.03s
# 536:	learn: 2.0238625	total: 3.51s	remaining: 3.03s
# 537:	learn: 2.0209241	total: 3.52s	remaining: 3.02s
# 538:	learn: 2.0182876	total: 3.52s	remaining: 3.01s
# 539:	learn: 2.0150690	total: 3.53s	remaining: 3s
# 540:	learn: 2.0120626	total: 3.53s	remaining: 3s
# 541:	learn: 2.0095817	total: 3.54s	remaining: 2.99s
# 542:	learn: 2.0051969	total: 3.55s	remaining: 2.98s
# 543:	learn: 2.0034326	total: 3.55s	remaining: 2.98s
# 544:	learn: 2.0012347	total: 3.56s	remaining: 2.97s
# 545:	learn: 1.9979617	total: 3.56s	remaining: 2.96s
# 546:	learn: 1.9970639	total: 3.57s	remaining: 2.96s
# 547:	learn: 1.9926827	total: 3.58s	remaining: 2.95s
# 548:	learn: 1.9901583	total: 3.58s	remaining: 2.94s
# 549:	learn: 1.9871440	total: 3.59s	remaining: 2.94s
# 550:	learn: 1.9847131	total: 3.6s	remaining: 2.93s
# 551:	learn: 1.9818983	total: 3.6s	remaining: 2.92s
# 552:	learn: 1.9804733	total: 3.61s	remaining: 2.92s
# 553:	learn: 1.9767131	total: 3.62s	remaining: 2.91s
# 554:	learn: 1.9751050	total: 3.62s	remaining: 2.9s
# 555:	learn: 1.9736747	total: 3.63s	remaining: 2.9s
# 556:	learn: 1.9701633	total: 3.63s	remaining: 2.89s
# 557:	learn: 1.9692226	total: 3.64s	remaining: 2.88s
# 558:	learn: 1.9657712	total: 3.65s	remaining: 2.88s
# 559:	learn: 1.9652733	total: 3.65s	remaining: 2.87s
# 560:	learn: 1.9635808	total: 3.66s	remaining: 2.86s
# 561:	learn: 1.9625219	total: 3.66s	remaining: 2.86s
# 562:	learn: 1.9589510	total: 3.67s	remaining: 2.85s
# 563:	learn: 1.9563079	total: 3.68s	remaining: 2.84s
# 564:	learn: 1.9549618	total: 3.68s	remaining: 2.84s
# 565:	learn: 1.9537595	total: 3.69s	remaining: 2.83s
# 566:	learn: 1.9524367	total: 3.69s	remaining: 2.82s
# 567:	learn: 1.9506969	total: 3.7s	remaining: 2.82s
# 568:	learn: 1.9493431	total: 3.71s	remaining: 2.81s
# 569:	learn: 1.9484430	total: 3.71s	remaining: 2.8s
# 570:	learn: 1.9473973	total: 3.72s	remaining: 2.79s
# 571:	learn: 1.9461018	total: 3.73s	remaining: 2.79s
# 572:	learn: 1.9456480	total: 3.73s	remaining: 2.78s
# 573:	learn: 1.9443534	total: 3.74s	remaining: 2.77s
# 574:	learn: 1.9435691	total: 3.74s	remaining: 2.77s
# 575:	learn: 1.9414467	total: 3.75s	remaining: 2.76s
# 576:	learn: 1.9399743	total: 3.76s	remaining: 2.75s
# 577:	learn: 1.9384851	total: 3.76s	remaining: 2.75s
# 578:	learn: 1.9378444	total: 3.77s	remaining: 2.74s
# 579:	learn: 1.9351633	total: 3.77s	remaining: 2.73s
# 580:	learn: 1.9341085	total: 3.78s	remaining: 2.73s
# 581:	learn: 1.9336789	total: 3.79s	remaining: 2.72s
# 582:	learn: 1.9333262	total: 3.79s	remaining: 2.71s
# 583:	learn: 1.9320764	total: 3.8s	remaining: 2.7s
# 584:	learn: 1.9314000	total: 3.8s	remaining: 2.7s
# 585:	learn: 1.9294100	total: 3.81s	remaining: 2.69s
# 586:	learn: 1.9286237	total: 3.81s	remaining: 2.68s
# 587:	learn: 1.9273670	total: 3.82s	remaining: 2.68s
# 588:	learn: 1.9268563	total: 3.83s	remaining: 2.67s
# 589:	learn: 1.9249265	total: 3.83s	remaining: 2.66s
# 590:	learn: 1.9234605	total: 3.84s	remaining: 2.66s
# 591:	learn: 1.9228059	total: 3.85s	remaining: 2.65s
# 592:	learn: 1.9206282	total: 3.85s	remaining: 2.64s
# 593:	learn: 1.9180612	total: 3.86s	remaining: 2.64s
# 594:	learn: 1.9173122	total: 3.86s	remaining: 2.63s
# 595:	learn: 1.9158991	total: 3.87s	remaining: 2.62s
# 596:	learn: 1.9148003	total: 3.88s	remaining: 2.62s
# 597:	learn: 1.9136799	total: 3.88s	remaining: 2.61s
# 598:	learn: 1.9134824	total: 3.89s	remaining: 2.6s
# 599:	learn: 1.9117550	total: 3.89s	remaining: 2.6s
# 600:	learn: 1.9094051	total: 3.9s	remaining: 2.59s
# 601:	learn: 1.9086639	total: 3.9s	remaining: 2.58s
# 602:	learn: 1.9082237	total: 3.91s	remaining: 2.58s
# 603:	learn: 1.9077883	total: 3.92s	remaining: 2.57s
# 604:	learn: 1.9073052	total: 3.92s	remaining: 2.56s
# 605:	learn: 1.9066521	total: 3.93s	remaining: 2.56s
# 606:	learn: 1.9054971	total: 3.94s	remaining: 2.55s
# 607:	learn: 1.9046847	total: 3.94s	remaining: 2.54s
# 608:	learn: 1.9039651	total: 3.95s	remaining: 2.54s
# 609:	learn: 1.9007358	total: 3.96s	remaining: 2.53s
# 610:	learn: 1.8987916	total: 3.96s	remaining: 2.52s
# 611:	learn: 1.8985348	total: 3.97s	remaining: 2.52s
# 612:	learn: 1.8952158	total: 3.97s	remaining: 2.51s
# 613:	learn: 1.8930777	total: 3.98s	remaining: 2.5s
# 614:	learn: 1.8920549	total: 3.99s	remaining: 2.5s
# 615:	learn: 1.8914044	total: 3.99s	remaining: 2.49s
# 616:	learn: 1.8910398	total: 4s	remaining: 2.48s
# 617:	learn: 1.8899794	total: 4s	remaining: 2.47s
# 618:	learn: 1.8888088	total: 4.01s	remaining: 2.47s
# 619:	learn: 1.8875261	total: 4.01s	remaining: 2.46s
# 620:	learn: 1.8870373	total: 4.02s	remaining: 2.45s
# 621:	learn: 1.8855755	total: 4.03s	remaining: 2.45s
# 622:	learn: 1.8844795	total: 4.03s	remaining: 2.44s
# 623:	learn: 1.8833944	total: 4.04s	remaining: 2.43s
# 624:	learn: 1.8824792	total: 4.04s	remaining: 2.43s
# 625:	learn: 1.8812482	total: 4.05s	remaining: 2.42s
# 626:	learn: 1.8790153	total: 4.06s	remaining: 2.41s
# 627:	learn: 1.8779846	total: 4.06s	remaining: 2.41s
# 628:	learn: 1.8774362	total: 4.07s	remaining: 2.4s
# 629:	learn: 1.8757979	total: 4.08s	remaining: 2.39s
# 630:	learn: 1.8747775	total: 4.08s	remaining: 2.39s
# 631:	learn: 1.8726549	total: 4.09s	remaining: 2.38s
# 632:	learn: 1.8710809	total: 4.09s	remaining: 2.37s
# 633:	learn: 1.8705265	total: 4.1s	remaining: 2.37s
# 634:	learn: 1.8691096	total: 4.11s	remaining: 2.36s
# 635:	learn: 1.8682001	total: 4.11s	remaining: 2.35s
# 636:	learn: 1.8663813	total: 4.12s	remaining: 2.35s
# 637:	learn: 1.8660715	total: 4.12s	remaining: 2.34s
# 638:	learn: 1.8654726	total: 4.13s	remaining: 2.33s
# 639:	learn: 1.8624256	total: 4.14s	remaining: 2.33s
# 640:	learn: 1.8613156	total: 4.14s	remaining: 2.32s
# 641:	learn: 1.8585102	total: 4.15s	remaining: 2.31s
# 642:	learn: 1.8577590	total: 4.15s	remaining: 2.31s
# 643:	learn: 1.8548127	total: 4.16s	remaining: 2.3s
# 644:	learn: 1.8535552	total: 4.17s	remaining: 2.29s
# 645:	learn: 1.8527839	total: 4.17s	remaining: 2.29s
# 646:	learn: 1.8508833	total: 4.18s	remaining: 2.28s
# 647:	learn: 1.8502797	total: 4.18s	remaining: 2.27s
# 648:	learn: 1.8496067	total: 4.19s	remaining: 2.27s
# 649:	learn: 1.8477674	total: 4.2s	remaining: 2.26s
# 650:	learn: 1.8464868	total: 4.2s	remaining: 2.25s
# 651:	learn: 1.8443745	total: 4.21s	remaining: 2.25s
# 652:	learn: 1.8434671	total: 4.21s	remaining: 2.24s
# 653:	learn: 1.8418644	total: 4.22s	remaining: 2.23s
# 654:	learn: 1.8412947	total: 4.22s	remaining: 2.23s
# 655:	learn: 1.8404858	total: 4.23s	remaining: 2.22s
# 656:	learn: 1.8397395	total: 4.24s	remaining: 2.21s
# 657:	learn: 1.8393685	total: 4.24s	remaining: 2.21s
# 658:	learn: 1.8382744	total: 4.25s	remaining: 2.2s
# 659:	learn: 1.8375555	total: 4.25s	remaining: 2.19s
# 660:	learn: 1.8367495	total: 4.26s	remaining: 2.19s
# 661:	learn: 1.8356922	total: 4.27s	remaining: 2.18s
# 662:	learn: 1.8339174	total: 4.27s	remaining: 2.17s
# 663:	learn: 1.8321652	total: 4.28s	remaining: 2.17s
# 664:	learn: 1.8305038	total: 4.29s	remaining: 2.16s
# 665:	learn: 1.8281415	total: 4.29s	remaining: 2.15s
# 666:	learn: 1.8267716	total: 4.3s	remaining: 2.15s
# 667:	learn: 1.8246038	total: 4.3s	remaining: 2.14s
# 668:	learn: 1.8229080	total: 4.31s	remaining: 2.13s
# 669:	learn: 1.8219808	total: 4.32s	remaining: 2.13s
# 670:	learn: 1.8216477	total: 4.32s	remaining: 2.12s
# 671:	learn: 1.8191839	total: 4.33s	remaining: 2.11s
# 672:	learn: 1.8181063	total: 4.33s	remaining: 2.1s
# 673:	learn: 1.8168177	total: 4.34s	remaining: 2.1s
# 674:	learn: 1.8139720	total: 4.35s	remaining: 2.09s
# 675:	learn: 1.8137203	total: 4.35s	remaining: 2.08s
# 676:	learn: 1.8130292	total: 4.36s	remaining: 2.08s
# 677:	learn: 1.8122367	total: 4.36s	remaining: 2.07s
# 678:	learn: 1.8112920	total: 4.37s	remaining: 2.07s
# 679:	learn: 1.8104531	total: 4.38s	remaining: 2.06s
# 680:	learn: 1.8090606	total: 4.38s	remaining: 2.05s
# 681:	learn: 1.8085811	total: 4.39s	remaining: 2.05s
# 682:	learn: 1.8071763	total: 4.39s	remaining: 2.04s
# 683:	learn: 1.8061208	total: 4.4s	remaining: 2.03s
# 684:	learn: 1.8055830	total: 4.41s	remaining: 2.03s
# 685:	learn: 1.8044004	total: 4.41s	remaining: 2.02s
# 686:	learn: 1.8038997	total: 4.42s	remaining: 2.01s
# 687:	learn: 1.8025632	total: 4.42s	remaining: 2.01s
# 688:	learn: 1.8020747	total: 4.43s	remaining: 2s
# 689:	learn: 1.8016492	total: 4.44s	remaining: 1.99s
# 690:	learn: 1.8014094	total: 4.44s	remaining: 1.99s
# 691:	learn: 1.8003192	total: 4.45s	remaining: 1.98s
# 692:	learn: 1.8000771	total: 4.45s	remaining: 1.97s
# 693:	learn: 1.7999012	total: 4.46s	remaining: 1.97s
# 694:	learn: 1.7972295	total: 4.47s	remaining: 1.96s
# 695:	learn: 1.7967409	total: 4.47s	remaining: 1.95s
# 696:	learn: 1.7947833	total: 4.48s	remaining: 1.95s
# 697:	learn: 1.7945904	total: 4.49s	remaining: 1.94s
# 698:	learn: 1.7941407	total: 4.49s	remaining: 1.93s
# 699:	learn: 1.7929884	total: 4.5s	remaining: 1.93s
# 700:	learn: 1.7927879	total: 4.5s	remaining: 1.92s
# 701:	learn: 1.7916924	total: 4.51s	remaining: 1.91s
# 702:	learn: 1.7913312	total: 4.51s	remaining: 1.91s
# 703:	learn: 1.7902580	total: 4.52s	remaining: 1.9s
# 704:	learn: 1.7885571	total: 4.53s	remaining: 1.89s
# 705:	learn: 1.7875477	total: 4.53s	remaining: 1.89s
# 706:	learn: 1.7867513	total: 4.54s	remaining: 1.88s
# 707:	learn: 1.7860095	total: 4.54s	remaining: 1.87s
# 708:	learn: 1.7857448	total: 4.55s	remaining: 1.87s
# 709:	learn: 1.7853911	total: 4.55s	remaining: 1.86s
# 710:	learn: 1.7849545	total: 4.56s	remaining: 1.85s
# 711:	learn: 1.7843170	total: 4.57s	remaining: 1.85s
# 712:	learn: 1.7841820	total: 4.57s	remaining: 1.84s
# 713:	learn: 1.7831682	total: 4.58s	remaining: 1.83s
# 714:	learn: 1.7820720	total: 4.58s	remaining: 1.83s
# 715:	learn: 1.7819176	total: 4.59s	remaining: 1.82s
# 716:	learn: 1.7816090	total: 4.59s	remaining: 1.81s
# 717:	learn: 1.7806888	total: 4.6s	remaining: 1.81s
# 718:	learn: 1.7802942	total: 4.61s	remaining: 1.8s
# 719:	learn: 1.7795102	total: 4.61s	remaining: 1.79s
# 720:	learn: 1.7789343	total: 4.62s	remaining: 1.79s
# 721:	learn: 1.7767774	total: 4.62s	remaining: 1.78s
# 722:	learn: 1.7754723	total: 4.63s	remaining: 1.77s
# 723:	learn: 1.7747670	total: 4.64s	remaining: 1.77s
# 724:	learn: 1.7739636	total: 4.64s	remaining: 1.76s
# 725:	learn: 1.7712895	total: 4.65s	remaining: 1.75s
# 726:	learn: 1.7708162	total: 4.66s	remaining: 1.75s
# 727:	learn: 1.7696754	total: 4.66s	remaining: 1.74s
# 728:	learn: 1.7693126	total: 4.67s	remaining: 1.74s
# 729:	learn: 1.7679131	total: 4.67s	remaining: 1.73s
# 730:	learn: 1.7671009	total: 4.68s	remaining: 1.72s
# 731:	learn: 1.7664627	total: 4.69s	remaining: 1.72s
# 732:	learn: 1.7650365	total: 4.69s	remaining: 1.71s
# 733:	learn: 1.7642436	total: 4.7s	remaining: 1.7s
# 734:	learn: 1.7641013	total: 4.71s	remaining: 1.7s
# 735:	learn: 1.7605153	total: 4.71s	remaining: 1.69s
# 736:	learn: 1.7604618	total: 4.72s	remaining: 1.68s
# 737:	learn: 1.7586760	total: 4.72s	remaining: 1.68s
# 738:	learn: 1.7583827	total: 4.73s	remaining: 1.67s
# 739:	learn: 1.7568984	total: 4.73s	remaining: 1.66s
# 740:	learn: 1.7563847	total: 4.74s	remaining: 1.66s
# 741:	learn: 1.7559200	total: 4.75s	remaining: 1.65s
# 742:	learn: 1.7549606	total: 4.75s	remaining: 1.64s
# 743:	learn: 1.7540537	total: 4.76s	remaining: 1.64s
# 744:	learn: 1.7527228	total: 4.76s	remaining: 1.63s
# 745:	learn: 1.7508259	total: 4.77s	remaining: 1.62s
# 746:	learn: 1.7484707	total: 4.78s	remaining: 1.62s
# 747:	learn: 1.7469503	total: 4.78s	remaining: 1.61s
# 748:	learn: 1.7451548	total: 4.79s	remaining: 1.6s
# 749:	learn: 1.7430399	total: 4.79s	remaining: 1.6s
# 750:	learn: 1.7422968	total: 4.8s	remaining: 1.59s
# 751:	learn: 1.7406099	total: 4.8s	remaining: 1.58s
# 752:	learn: 1.7391233	total: 4.81s	remaining: 1.58s
# 753:	learn: 1.7371965	total: 4.82s	remaining: 1.57s
# 754:	learn: 1.7364181	total: 4.82s	remaining: 1.56s
# 755:	learn: 1.7353829	total: 4.83s	remaining: 1.56s
# 756:	learn: 1.7349066	total: 4.83s	remaining: 1.55s
# 757:	learn: 1.7332451	total: 4.84s	remaining: 1.54s
# 758:	learn: 1.7318392	total: 4.85s	remaining: 1.54s
# 759:	learn: 1.7310900	total: 4.85s	remaining: 1.53s
# 760:	learn: 1.7297002	total: 4.86s	remaining: 1.53s
# 761:	learn: 1.7290935	total: 4.87s	remaining: 1.52s
# 762:	learn: 1.7284102	total: 4.87s	remaining: 1.51s
# 763:	learn: 1.7267665	total: 4.88s	remaining: 1.51s
# 764:	learn: 1.7256839	total: 4.88s	remaining: 1.5s
# 765:	learn: 1.7254281	total: 4.89s	remaining: 1.49s
# 766:	learn: 1.7245001	total: 4.89s	remaining: 1.49s
# 767:	learn: 1.7230791	total: 4.9s	remaining: 1.48s
# 768:	learn: 1.7220512	total: 4.91s	remaining: 1.47s
# 769:	learn: 1.7217286	total: 4.91s	remaining: 1.47s
# 770:	learn: 1.7190390	total: 4.92s	remaining: 1.46s
# 771:	learn: 1.7163144	total: 4.93s	remaining: 1.45s
# 772:	learn: 1.7135930	total: 4.93s	remaining: 1.45s
# 773:	learn: 1.7116525	total: 4.94s	remaining: 1.44s
# 774:	learn: 1.7110681	total: 4.95s	remaining: 1.44s
# 775:	learn: 1.7095099	total: 4.95s	remaining: 1.43s
# 776:	learn: 1.7079985	total: 4.96s	remaining: 1.42s
# 777:	learn: 1.7071942	total: 4.96s	remaining: 1.42s
# 778:	learn: 1.7055409	total: 4.97s	remaining: 1.41s
# 779:	learn: 1.7037289	total: 4.98s	remaining: 1.4s
# 780:	learn: 1.7023381	total: 4.98s	remaining: 1.4s
# 781:	learn: 1.6997325	total: 4.99s	remaining: 1.39s
# 782:	learn: 1.6992852	total: 5s	remaining: 1.38s
# 783:	learn: 1.6979703	total: 5s	remaining: 1.38s
# 784:	learn: 1.6964938	total: 5.01s	remaining: 1.37s
# 785:	learn: 1.6943317	total: 5.01s	remaining: 1.36s
# 786:	learn: 1.6931219	total: 5.02s	remaining: 1.36s
# 787:	learn: 1.6920491	total: 5.02s	remaining: 1.35s
# 788:	learn: 1.6909994	total: 5.03s	remaining: 1.34s
# 789:	learn: 1.6895124	total: 5.04s	remaining: 1.34s
# 790:	learn: 1.6883800	total: 5.04s	remaining: 1.33s
# 791:	learn: 1.6880423	total: 5.05s	remaining: 1.32s
# 792:	learn: 1.6877684	total: 5.05s	remaining: 1.32s
# 793:	learn: 1.6875855	total: 5.06s	remaining: 1.31s
# 794:	learn: 1.6865459	total: 5.07s	remaining: 1.31s
# 795:	learn: 1.6861155	total: 5.07s	remaining: 1.3s
# 796:	learn: 1.6855722	total: 5.08s	remaining: 1.29s
# 797:	learn: 1.6847238	total: 5.08s	remaining: 1.29s
# 798:	learn: 1.6835440	total: 5.09s	remaining: 1.28s
# 799:	learn: 1.6832542	total: 5.1s	remaining: 1.27s
# 800:	learn: 1.6825379	total: 5.1s	remaining: 1.27s
# 801:	learn: 1.6817022	total: 5.11s	remaining: 1.26s
# 802:	learn: 1.6803637	total: 5.11s	remaining: 1.25s
# 803:	learn: 1.6790165	total: 5.12s	remaining: 1.25s
# 804:	learn: 1.6784922	total: 5.13s	remaining: 1.24s
# 805:	learn: 1.6782542	total: 5.13s	remaining: 1.24s
# 806:	learn: 1.6777917	total: 5.14s	remaining: 1.23s
# 807:	learn: 1.6775546	total: 5.14s	remaining: 1.22s
# 808:	learn: 1.6771630	total: 5.15s	remaining: 1.22s
# 809:	learn: 1.6766105	total: 5.16s	remaining: 1.21s
# 810:	learn: 1.6759381	total: 5.16s	remaining: 1.2s
# 811:	learn: 1.6755507	total: 5.17s	remaining: 1.2s
# 812:	learn: 1.6743686	total: 5.18s	remaining: 1.19s
# 813:	learn: 1.6722635	total: 5.18s	remaining: 1.18s
# 814:	learn: 1.6721213	total: 5.19s	remaining: 1.18s
# 815:	learn: 1.6719174	total: 5.19s	remaining: 1.17s
# 816:	learn: 1.6717409	total: 5.2s	remaining: 1.16s
# 817:	learn: 1.6702773	total: 5.21s	remaining: 1.16s
# 818:	learn: 1.6683590	total: 5.21s	remaining: 1.15s
# 819:	learn: 1.6681250	total: 5.22s	remaining: 1.15s
# 820:	learn: 1.6661813	total: 5.23s	remaining: 1.14s
# 821:	learn: 1.6653755	total: 5.23s	remaining: 1.13s
# 822:	learn: 1.6649318	total: 5.24s	remaining: 1.13s
# 823:	learn: 1.6645192	total: 5.25s	remaining: 1.12s
# 824:	learn: 1.6632923	total: 5.25s	remaining: 1.11s
# 825:	learn: 1.6630149	total: 5.26s	remaining: 1.11s
# 826:	learn: 1.6628558	total: 5.27s	remaining: 1.1s
# 827:	learn: 1.6623361	total: 5.27s	remaining: 1.09s
# 828:	learn: 1.6609716	total: 5.28s	remaining: 1.09s
# 829:	learn: 1.6603546	total: 5.28s	remaining: 1.08s
# 830:	learn: 1.6598870	total: 5.29s	remaining: 1.07s
# 831:	learn: 1.6593306	total: 5.3s	remaining: 1.07s
# 832:	learn: 1.6586040	total: 5.3s	remaining: 1.06s
# 833:	learn: 1.6584356	total: 5.31s	remaining: 1.06s
# 834:	learn: 1.6579939	total: 5.31s	remaining: 1.05s
# 835:	learn: 1.6568149	total: 5.32s	remaining: 1.04s
# 836:	learn: 1.6563882	total: 5.33s	remaining: 1.04s
# 837:	learn: 1.6556568	total: 5.33s	remaining: 1.03s
# 838:	learn: 1.6551722	total: 5.34s	remaining: 1.02s
# 839:	learn: 1.6540542	total: 5.34s	remaining: 1.02s
# 840:	learn: 1.6524273	total: 5.35s	remaining: 1.01s
# 841:	learn: 1.6511951	total: 5.36s	remaining: 1s
# 842:	learn: 1.6508618	total: 5.36s	remaining: 998ms
# 843:	learn: 1.6498687	total: 5.37s	remaining: 992ms
# 844:	learn: 1.6496095	total: 5.37s	remaining: 986ms
# 845:	learn: 1.6468282	total: 5.38s	remaining: 979ms
# 846:	learn: 1.6451219	total: 5.38s	remaining: 973ms
# 847:	learn: 1.6445059	total: 5.39s	remaining: 966ms
# 848:	learn: 1.6443886	total: 5.4s	remaining: 960ms
# 849:	learn: 1.6438383	total: 5.4s	remaining: 954ms
# 850:	learn: 1.6422614	total: 5.41s	remaining: 947ms
# 851:	learn: 1.6413490	total: 5.42s	remaining: 941ms
# 852:	learn: 1.6404035	total: 5.42s	remaining: 934ms
# 853:	learn: 1.6392899	total: 5.43s	remaining: 928ms
# 854:	learn: 1.6385190	total: 5.43s	remaining: 921ms
# 855:	learn: 1.6370219	total: 5.44s	remaining: 915ms
# 856:	learn: 1.6347693	total: 5.45s	remaining: 909ms
# 857:	learn: 1.6339623	total: 5.45s	remaining: 902ms
# 858:	learn: 1.6328870	total: 5.46s	remaining: 896ms
# 859:	learn: 1.6324276	total: 5.46s	remaining: 890ms
# 860:	learn: 1.6312424	total: 5.47s	remaining: 883ms
# 861:	learn: 1.6306934	total: 5.48s	remaining: 877ms
# 862:	learn: 1.6291335	total: 5.48s	remaining: 871ms
# 863:	learn: 1.6285692	total: 5.49s	remaining: 864ms
# 864:	learn: 1.6283528	total: 5.49s	remaining: 858ms
# 865:	learn: 1.6282008	total: 5.5s	remaining: 851ms
# 866:	learn: 1.6277440	total: 5.51s	remaining: 845ms
# 867:	learn: 1.6267284	total: 5.51s	remaining: 838ms
# 868:	learn: 1.6253196	total: 5.52s	remaining: 832ms
# 869:	learn: 1.6248030	total: 5.52s	remaining: 825ms
# 870:	learn: 1.6244137	total: 5.53s	remaining: 819ms
# 871:	learn: 1.6239503	total: 5.54s	remaining: 813ms
# 872:	learn: 1.6224101	total: 5.54s	remaining: 806ms
# 873:	learn: 1.6219838	total: 5.55s	remaining: 800ms
# 874:	learn: 1.6209013	total: 5.55s	remaining: 793ms
# 875:	learn: 1.6193333	total: 5.56s	remaining: 787ms
# 876:	learn: 1.6183883	total: 5.57s	remaining: 781ms
# 877:	learn: 1.6181782	total: 5.57s	remaining: 774ms
# 878:	learn: 1.6158827	total: 5.58s	remaining: 768ms
# 879:	learn: 1.6154494	total: 5.58s	remaining: 761ms
# 880:	learn: 1.6150423	total: 5.59s	remaining: 755ms
# 881:	learn: 1.6148183	total: 5.59s	remaining: 749ms
# 882:	learn: 1.6135350	total: 5.6s	remaining: 742ms
# 883:	learn: 1.6126702	total: 5.61s	remaining: 736ms
# 884:	learn: 1.6120778	total: 5.61s	remaining: 729ms
# 885:	learn: 1.6115441	total: 5.62s	remaining: 723ms
# 886:	learn: 1.6113487	total: 5.62s	remaining: 717ms
# 887:	learn: 1.6110731	total: 5.63s	remaining: 710ms
# 888:	learn: 1.6099362	total: 5.64s	remaining: 704ms
# 889:	learn: 1.6082499	total: 5.64s	remaining: 697ms
# 890:	learn: 1.6077668	total: 5.65s	remaining: 691ms
# 891:	learn: 1.6063929	total: 5.65s	remaining: 685ms
# 892:	learn: 1.6062636	total: 5.66s	remaining: 678ms
# 893:	learn: 1.6059954	total: 5.67s	remaining: 672ms
# 894:	learn: 1.6057608	total: 5.67s	remaining: 666ms
# 895:	learn: 1.6051710	total: 5.68s	remaining: 659ms
# 896:	learn: 1.6047276	total: 5.68s	remaining: 653ms
# 897:	learn: 1.6044421	total: 5.69s	remaining: 646ms
# 898:	learn: 1.6040407	total: 5.7s	remaining: 640ms
# 899:	learn: 1.6036843	total: 5.7s	remaining: 634ms
# 900:	learn: 1.6026620	total: 5.71s	remaining: 627ms
# 901:	learn: 1.6017323	total: 5.71s	remaining: 621ms
# 902:	learn: 1.6012053	total: 5.72s	remaining: 615ms
# 903:	learn: 1.6009995	total: 5.73s	remaining: 608ms
# 904:	learn: 1.6002808	total: 5.73s	remaining: 602ms
# 905:	learn: 1.5993404	total: 5.74s	remaining: 595ms
# 906:	learn: 1.5989050	total: 5.74s	remaining: 589ms
# 907:	learn: 1.5987664	total: 5.75s	remaining: 583ms
# 908:	learn: 1.5981393	total: 5.76s	remaining: 576ms
# 909:	learn: 1.5968606	total: 5.76s	remaining: 570ms
# 910:	learn: 1.5961186	total: 5.77s	remaining: 564ms
# 911:	learn: 1.5952501	total: 5.77s	remaining: 557ms
# 912:	learn: 1.5947013	total: 5.78s	remaining: 551ms
# 913:	learn: 1.5943499	total: 5.79s	remaining: 544ms
# 914:	learn: 1.5939377	total: 5.79s	remaining: 538ms
# 915:	learn: 1.5934473	total: 5.8s	remaining: 532ms
# 916:	learn: 1.5927497	total: 5.8s	remaining: 525ms
# 917:	learn: 1.5921438	total: 5.81s	remaining: 519ms
# 918:	learn: 1.5918739	total: 5.82s	remaining: 513ms
# 919:	learn: 1.5917490	total: 5.82s	remaining: 506ms
# 920:	learn: 1.5912539	total: 5.83s	remaining: 500ms
# 921:	learn: 1.5910222	total: 5.83s	remaining: 494ms
# 922:	learn: 1.5909833	total: 5.84s	remaining: 487ms
# 923:	learn: 1.5906332	total: 5.84s	remaining: 481ms
# 924:	learn: 1.5890167	total: 5.85s	remaining: 474ms
# 925:	learn: 1.5883105	total: 5.86s	remaining: 468ms
# 926:	learn: 1.5881345	total: 5.86s	remaining: 462ms
# 927:	learn: 1.5866628	total: 5.87s	remaining: 455ms
# 928:	learn: 1.5865529	total: 5.88s	remaining: 449ms
# 929:	learn: 1.5862652	total: 5.88s	remaining: 443ms
# 930:	learn: 1.5840521	total: 5.89s	remaining: 437ms
# 931:	learn: 1.5837736	total: 5.9s	remaining: 430ms
# 932:	learn: 1.5834595	total: 5.9s	remaining: 424ms
# 933:	learn: 1.5830841	total: 5.91s	remaining: 418ms
# 934:	learn: 1.5829395	total: 5.92s	remaining: 411ms
# 935:	learn: 1.5824371	total: 5.92s	remaining: 405ms
# 936:	learn: 1.5815710	total: 5.93s	remaining: 399ms
# 937:	learn: 1.5803197	total: 5.94s	remaining: 392ms
# 938:	learn: 1.5799194	total: 5.94s	remaining: 386ms
# 939:	learn: 1.5797406	total: 5.95s	remaining: 380ms
# 940:	learn: 1.5793019	total: 5.95s	remaining: 373ms
# 941:	learn: 1.5785152	total: 5.96s	remaining: 367ms
# 942:	learn: 1.5773885	total: 5.96s	remaining: 361ms
# 943:	learn: 1.5764109	total: 5.97s	remaining: 354ms
# 944:	learn: 1.5749368	total: 5.98s	remaining: 348ms
# 945:	learn: 1.5741410	total: 5.98s	remaining: 342ms
# 946:	learn: 1.5734268	total: 5.99s	remaining: 335ms
# 947:	learn: 1.5727066	total: 5.99s	remaining: 329ms
# 948:	learn: 1.5723392	total: 6s	remaining: 322ms
# 949:	learn: 1.5720278	total: 6s	remaining: 316ms
# 950:	learn: 1.5707903	total: 6.01s	remaining: 310ms
# 951:	learn: 1.5702490	total: 6.02s	remaining: 303ms
# 952:	learn: 1.5693301	total: 6.02s	remaining: 297ms
# 953:	learn: 1.5691485	total: 6.03s	remaining: 291ms
# 954:	learn: 1.5680642	total: 6.04s	remaining: 284ms
# 955:	learn: 1.5670352	total: 6.04s	remaining: 278ms
# 956:	learn: 1.5668060	total: 6.05s	remaining: 272ms
# 957:	learn: 1.5667337	total: 6.05s	remaining: 265ms
# 958:	learn: 1.5666644	total: 6.06s	remaining: 259ms
# 959:	learn: 1.5665372	total: 6.06s	remaining: 253ms
# 960:	learn: 1.5664681	total: 6.07s	remaining: 246ms
# 961:	learn: 1.5659075	total: 6.08s	remaining: 240ms
# 962:	learn: 1.5651279	total: 6.08s	remaining: 234ms
# 963:	learn: 1.5646231	total: 6.09s	remaining: 227ms
# 964:	learn: 1.5644833	total: 6.09s	remaining: 221ms
# 965:	learn: 1.5640790	total: 6.1s	remaining: 215ms
# 966:	learn: 1.5638566	total: 6.11s	remaining: 208ms
# 967:	learn: 1.5635421	total: 6.11s	remaining: 202ms
# 968:	learn: 1.5627978	total: 6.12s	remaining: 196ms
# 969:	learn: 1.5617482	total: 6.12s	remaining: 189ms
# 970:	learn: 1.5607571	total: 6.13s	remaining: 183ms
# 971:	learn: 1.5604065	total: 6.13s	remaining: 177ms
# 972:	learn: 1.5602876	total: 6.14s	remaining: 170ms
# 973:	learn: 1.5599034	total: 6.14s	remaining: 164ms
# 974:	learn: 1.5590770	total: 6.15s	remaining: 158ms
# 975:	learn: 1.5577709	total: 6.16s	remaining: 151ms
# 976:	learn: 1.5573053	total: 6.16s	remaining: 145ms
# 977:	learn: 1.5569250	total: 6.17s	remaining: 139ms
# 978:	learn: 1.5568889	total: 6.17s	remaining: 132ms
# 979:	learn: 1.5566689	total: 6.18s	remaining: 126ms
# 980:	learn: 1.5553366	total: 6.18s	remaining: 120ms
# 981:	learn: 1.5549587	total: 6.19s	remaining: 113ms
# 982:	learn: 1.5545808	total: 6.2s	remaining: 107ms
# 983:	learn: 1.5541144	total: 6.2s	remaining: 101ms
# 984:	learn: 1.5535233	total: 6.21s	remaining: 94.5ms
# 985:	learn: 1.5531067	total: 6.21s	remaining: 88.2ms
# 986:	learn: 1.5530079	total: 6.22s	remaining: 81.9ms
# 987:	learn: 1.5529370	total: 6.23s	remaining: 75.6ms
# 988:	learn: 1.5527387	total: 6.23s	remaining: 69.3ms
# 989:	learn: 1.5524353	total: 6.24s	remaining: 63ms
# 990:	learn: 1.5515250	total: 6.24s	remaining: 56.7ms
# 991:	learn: 1.5504654	total: 6.25s	remaining: 50.4ms
# 992:	learn: 1.5502533	total: 6.25s	remaining: 44.1ms
# 993:	learn: 1.5497365	total: 6.26s	remaining: 37.8ms
# 994:	learn: 1.5491134	total: 6.27s	remaining: 31.5ms
# 995:	learn: 1.5476622	total: 6.27s	remaining: 25.2ms
# 996:	learn: 1.5467813	total: 6.28s	remaining: 18.9ms
# 997:	learn: 1.5465932	total: 6.29s	remaining: 12.6ms
# 998:	learn: 1.5459427	total: 6.29s	remaining: 6.3ms
# 999:	learn: 1.5452879	total: 6.3s	remaining: 0us
# model used :  <catboost.core.CatBoostRegressor object at 0x0000021F3B361CD0>
# Mean Absolute Error :  0.7010289799371733
# Mean Squared Error :  3.4260374423682176
# R2 - score :  0.9962081291606372
# Adjusted R2 - score :  0.9961847673721006
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004096 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1606
# [LightGBM] [Info] Number of data points in the train set: 48342, number of used features: 74
# [LightGBM] [Info] Start training from score 99.303479
# model used :  LGBMRegressor()
# Mean Absolute Error :  3.234686963671678
# Mean Squared Error :  21.212309172467446
# R2 - score :  0.9765226335264366
# Adjusted R2 - score :  0.9763779890239769

# %%
scores_data = pd.DataFrame({"Model" : model_names,
                            "MAE" : mae_list,
                            "MSE" : mse_list,
                            "R2-score" : r2_list,
                            "Adjusted R2":adjr2_list})
scores_data
# Out:
#                        Model        MAE         MSE  R2-score  Adjusted R2
# 0           LinearRegression  24.216674  810.159338  0.103332     0.097807
# 1     SupportVectorRegressor  17.627628  601.380340  0.334404     0.330303
# 2      DecisionTreeRegressor   0.078250    2.687410  0.997026     0.997007
# 3      RandomForestRegressor   0.128880    1.699325  0.998119     0.998108
# 4               MLPRegressor   0.683103    3.578535  0.996039     0.996015
# 5              LGBMRegressor  17.512286  460.472259  0.490358     0.487218
# 6  GradientBoostingRegressor   0.701029    3.426037  0.996208     0.996185
# 7          CatBoostRegressor   3.234687   21.212309  0.976523     0.976378

# %%
scores_data.to_csv('cac_dataset/scores_dataset.csv', sep='\t', encoding='utf-8', index=False, header=True)

# %%
def preprocessor(X, split):
    X = X.drop(["avg_cars_at home(approx).1"], axis=1)
    X["avg. yearly_income"] = X['avg. yearly_income'].str.replace(r'\$', '', regex=True)

    def media_cleaner(value):
        if 'Daily' in value:
            value = "Daily Media"
        elif 'Sunday' in value:
            value = "Sunday Media"
        return value
    
    X["media_type"] = X["media_type"].apply(media_cleaner) 


    education_mapping = {"Partial High School": 1,"High School Degree": 2,"Partial College": 3,"Bachelors Degree": 4,"Graduate Degree": 5}
    houseowner_mapping = {"Y": 1, "N": 0}
    occupation_mapping = {'Manual' :1,'Skilled Manual':2,'Clerical':3,'Professional':4,'Management':5}
    member_card_mapping = {"Normal": 1,"Bronze": 2,"Silver": 3,"Golden": 4}
    income_mapping = {"10K - 30K": 1,"30K - 50K": 2,"50K - 70K": 3,"70K - 90K": 4,"90K - 110K": 5,"110K - 130K": 6,"130K - 150K": 7,"150K +": 8}
    car_mapping = {"0 car": 0.0,"1 car": 1.0,"2 car": 2.0,"3 car": 3.0,"4 car": 4.0}
    weights = {"education_encoded": 0.1,"houseowner_encoded": 0.15,"member_card_encoded": 0.2,"income_encoded": 0.3, "occupation_encoded": 0.1,"cars_at_home" : 0.15}
    X["profile_strength"] = (
        (X["education"].map(education_mapping)) * weights["education_encoded"] +
        (X["houseowner"].map(houseowner_mapping)) * weights["houseowner_encoded"] +
        (X["member_card"].map(member_card_mapping)) * weights["member_card_encoded"] +
        (X["avg. yearly_income"].map(income_mapping)) * weights["income_encoded"] +
        (X["occupation"].map(occupation_mapping)) * weights["occupation_encoded"] +
        (X["avg_cars_at home(approx)"]) * weights["cars_at_home"] 
    ) 
    ordinal_cat = ["education","occupation","member_card","avg. yearly_income","store_type"]


    codes = [0,1,2,3,4,5,6,7]
    ed_map = {"education" : ["Partial High School","High School Degree","Partial College","Bachelors Degree","Graduate Degree"],"encoding_values" : codes[:5]}
    mem_map = {"member_card":["Normal","Bronze","Silver","Golden"],"encoding_values" : codes[:4]}
    occ_map = {"occupation" : ['Manual', 'Skilled Manual', 'Clerical', 'Professional', 'Management'],"encoding_values" : codes[:5]}
    inc_map = {"avg. yearly_income" :['10K - 30K', '30K - 50K', '50K - 70K', '70K - 90K','90K - 110K', '110K - 130K', '130K - 150K', '150K +'],"encoding_values" : codes}
    store_map = {"store_type":['Small Grocery', 'Mid-Size Grocery', 'Supermarket', 'Gourmet Supermarket', 'Deluxe Supermarket'],"encoding_values" : codes[:5]}
    ordinal_order = [ed_map[ordinal_cat[0]],occ_map[ordinal_cat[1]],mem_map[ordinal_cat[2]],inc_map[ordinal_cat[3]],store_map[ordinal_cat[4]]]
    for i in range(len(ordinal_order)):
        X[ordinal_cat[i]] = pd.Categorical(X[ordinal_cat[i]], categories=ordinal_order[i], ordered=True).codes

    def get_stats(data,col):
        data_column = data[col]
        op_mean = np.mean(data_column)
        op_median = np.median(data_column)
        op_std = np.std(data_column)
        op_var = np.var(data_column)
        op_min = np.min(data_column)
        op_max = np.max(data_column)
        op_1q = data_column.quantile(0.25)
        op_3q = data_column.quantile(0.75)
        op_iqr = op_3q - op_1q
        op_upper = min((op_3q + 1.5*(op_iqr)),data_column.max())
        op_lower = max((op_1q - 1.5*(op_iqr)),data_column.min())
        op_outliers = ((data_column < op_lower) | (data_column > op_upper)).sum()
        dic_stats = {"Mean": [op_mean],
                    "Median":[op_median],
                    "Standard-Deviation": [op_std],
                    "Variance": [op_var],
                    "Minimum Value": [op_min],
                    "Maximum Value": [op_max],
                    "Q1": [op_1q],
                    "Q3": [op_3q],
                    "IQR": [op_iqr],
                    "Upper Fence":[op_upper],
                    "Lower Fence": [op_lower],
                    "Outliers count":[op_outliers]}

        return dic_stats
    
    dic_sales = get_stats(X, "store_sales(in millions)") 
    X["store_sales(in millions)"] = np.where(X["store_sales(in millions)"] > dic_sales["Upper Fence"][0], dic_sales["Upper Fence"][0], (np.where(X["store_sales(in millions)"] < dic_sales["Lower Fence"][0], dic_sales["Lower Fence"][0], X["store_sales(in millions)"])))
    dic_cost = get_stats(X, "store_cost(in millions)") 
    X["store_cost(in millions)"] = np.where(X["store_cost(in millions)"] > dic_cost["Upper Fence"][0], dic_cost["Upper Fence"][0], (np.where(X["store_cost(in millions)"] < dic_cost["Lower Fence"][0], dic_cost["Lower Fence"][0],X["store_cost(in millions)"])))


    train, test = train_test_split(X,test_size=split,random_state=42,shuffle=True)
    X_train = train.drop("cost", axis=1)
    X_test = test.drop("cost", axis=1)
    y_train = train["cost"]
    y_test = test["cost"]
     

    nominal_cat = X_train.select_dtypes('object').columns
    binary_encoder = ce.BinaryEncoder(cols=nominal_cat)
    X_train = binary_encoder.fit_transform(X_train)
    X_test = binary_encoder.transform(X_test)

    scaler = MinMaxScaler()
    X_train = pd.DataFrame(scaler.fit_transform(X_train), index=X_train.index, columns=X_train.columns)
    X_test = pd.DataFrame(scaler.fit_transform(X_test), index=X_test.index, columns=X_test.columns)

    return X_train, X_test, y_train, y_test

# %%
data = pd.read_csv(r'cac_dataset/customer_acquisition_costs.csv')

# %%
split_size = 0.15
X_train, X_test, y_train, y_test = preprocessor(data, split_size)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((51363, 74), (9065, 74), (51363,), (9065,))

# %%
grid = { 
    'n_estimators': [100,200,300,400,500],
    'max_features': ['sqrt', 'log2', None],
    'max_depth' : [None,4,5,6,7,8],
    'min_samples_split' : [2,6,10],
    'min_samples_leaf':[1,3,5,7],
    'bootstrap':[True, False],
    'oob_score' : [True, False]
    }

# %%
random_search = RandomizedSearchCV(RandomForestRegressor(), grid, n_iter=50, cv=5, n_jobs=-1, verbose=2)
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 4, 5, 6, 7, 8],
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'min_samples_leaf': [1, 3, 5, 7],
#                                         'min_samples_split': [2, 6, 10],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500],
#                                         'oob_score': [True, False]},
#                    verbose=2)

# %%
cv_results = pd.DataFrame(random_search.cv_results_).sort_values(by = 'rank_test_score')
cv_results.head(5)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 42     171.768685      0.775888         0.370350        0.039138
# 12      22.224756      0.513094         0.616083        0.026865
# 43      49.182122      2.549344         1.626756        0.396770
# 28       7.240027      0.258755         0.263374        0.021277
# 13     258.017296      4.235564         0.567689        0.083211
#
#     param_oob_score  param_n_estimators  param_min_samples_split  \
# 42             True                 300                       10
# 12             True                 200                        6
# 43             True                 500                        2
# 28            False                 100                       10
# 13            False                 400                        6
#
#     param_min_samples_leaf param_max_features param_max_depth  \
# 42                       3               None            None
# 12                       3               sqrt            None
# 43                       7               log2            None
# 28                       7               log2            None
# 13                       1               None               8
#
#     param_bootstrap                                             params  \
# 42             True  {'oob_score': True, 'n_estimators': 300, 'min_...
# 12             True  {'oob_score': True, 'n_estimators': 200, 'min_...
# 43             True  {'oob_score': True, 'n_estimators': 500, 'min_...
# 28             True  {'oob_score': False, 'n_estimators': 100, 'min...
# 13            False  {'oob_score': False, 'n_estimators': 400, 'min...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 42           0.997936           0.997656           0.997855
# 12           0.946312           0.945731           0.942262
# 43           0.852224           0.853348           0.850254
# 28           0.856940           0.854227           0.848913
# 13           0.839475           0.843293           0.830780
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 42           0.997291           0.997917         0.997731        0.000241
# 12           0.944043           0.946122         0.944894        0.001541
# 43           0.854424           0.852363         0.852523        0.001383
# 28           0.850151           0.845123         0.851071        0.004130
# 13           0.798911           0.838105         0.830113        0.016120
#
#     rank_test_score
# 42                1
# 12                2
# 43                3
# 28                4
# 13                5

# %%
cv_results.to_csv('cac_dataset/rcv_scores_dataset.csv', sep='\t', encoding='utf-8', index=False, header=True)

# %%
model_rf = RandomForestRegressor(n_estimators=300, min_samples_split=10,min_samples_leaf=3,bootstrap=True,oob_score=True)
model_rf.fit(X_train, y_train)
predicted_values_new = model_rf.predict(X_test)

# %%
mse = mean_squared_error(y_test,predicted_values_new)
r2_value = r2_score(y_test, predicted_values_new)
adjusted_r2 = 1 - (1-r2_value)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print("MSE : ",mse)
print("r2_score for first model : ",r2_value)
print("adjusted r2 : ",adjusted_r2)
# Out:
# MSE :  1.713679676666459
# r2_score for first model :  0.9980964122480205
# adjusted r2 :  0.9980807431163579

# %%
model_rf.feature_importances_
# Out:
# array([5.90060955e-06, 1.57028709e-05, 9.25639252e-06, 1.24579363e-05,
#        1.67362742e-05, 6.37807971e-06, 1.52896763e-05, 7.33396377e-06,
#        1.43433719e-05, 1.08004912e-05, 5.38200354e-06, 1.02950770e-05,
#        1.52839669e-05, 1.04229332e-04, 1.16092716e-04, 5.33653076e-05,
#        5.36530732e-02, 7.90271891e-02, 6.91414605e-02, 7.41039567e-02,
#        8.66137607e-02, 5.27211938e-02, 7.84029810e-03, 7.46931056e-03,
#        2.30025842e-05, 1.73222840e-05, 7.13172915e-05, 6.20571151e-05,
#        4.30099929e-04, 4.06928507e-04, 1.30065187e-04, 1.67179144e-04,
#        4.44611732e-05, 4.64945803e-05, 1.84749779e-04, 2.75559370e-04,
#        1.39450202e-04, 1.12233712e-05, 1.38879942e-05, 4.39731218e-05,
#        1.16691255e-05, 1.77473528e-05, 1.15520294e-05, 9.72887533e-06,
#        1.56460150e-04, 9.11535012e-05, 1.25601779e-04, 8.28150174e-06,
#        1.97423416e-05, 1.09599415e-04, 2.77494312e-02, 4.68232200e-03,
#        1.15520398e-02, 1.37809420e-02, 1.98020380e-02, 8.71985683e-03,
#        2.41590122e-03, 1.24543591e-02, 1.32527617e-02, 2.43032723e-02,
#        6.47227092e-02, 7.45270631e-02, 4.76691296e-02, 4.70272707e-02,
#        6.38888657e-03, 9.06168157e-03, 3.88565474e-03, 4.17739904e-03,
#        8.54024071e-03, 2.60512941e-02, 5.66708684e-02, 2.06759179e-02,
#        5.71984424e-02, 1.07211916e-03])

# %%
importances = model_rf.feature_importances_
feature_names = X_train.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances}).sort_values(by='Importance', ascending=False)

# %%
feature_list = []
mse_list = []
r2_list = []
adjr2_list = []
for i in range(5,50):
    top_features = feature_importance_df['Feature'][:i].values
    X_train_selected = X_train[top_features]
    X_test_selected = X_test[top_features]
    model_checked = RandomForestRegressor(n_estimators=300, min_samples_split=10,min_samples_leaf=3,bootstrap=True,oob_score=True)
    model_checked.fit(X_train_selected, y_train)
    predicted_values = model_checked.predict(X_test_selected)
    mse = mean_squared_error(y_test,predicted_values)
    mse_list.append(mse)
    r2_value = r2_score(y_test, predicted_values)
    r2_list.append(r2_value)
    adjusted_r2 = 1 - (1-r2_value)*(len(y_test)-1)/(len(y_test)-X_test_selected.shape[1]-1)
    adjr2_list.append(adjusted_r2)
    feature_list.append(i)
    print("run no..............  ",i)
    print("adjusted r2 score ::::::::::  ",adjusted_r2)
# Out:
# run no..............   5
# adjusted r2 score ::::::::::   0.644537585674265
# run no..............   6
# adjusted r2 score ::::::::::   0.6444211309859971
# run no..............   7
# adjusted r2 score ::::::::::   0.8500759294486382
# run no..............   8
# adjusted r2 score ::::::::::   0.9077152321335862
# run no..............   9
# adjusted r2 score ::::::::::   0.9566758317809717
# run no..............   10
# adjusted r2 score ::::::::::   0.9914466710114592
# run no..............   11
# adjusted r2 score ::::::::::   0.9914466768075686
# run no..............   12
# adjusted r2 score ::::::::::   0.9914486704731236
# run no..............   13
# adjusted r2 score ::::::::::   0.9914476528569195
# run no..............   14
# adjusted r2 score ::::::::::   0.996118949296434
# run no..............   15
# adjusted r2 score ::::::::::   0.9961150116262864
# run no..............   16
# adjusted r2 score ::::::::::   0.9964727432159579
# run no..............   17
# adjusted r2 score ::::::::::   0.9964746382864222
# run no..............   18
# adjusted r2 score ::::::::::   0.9964748852337126
# run no..............   19
# adjusted r2 score ::::::::::   0.9964758658482608
# run no..............   20
# adjusted r2 score ::::::::::   0.9964724840656801
# run no..............   21
# adjusted r2 score ::::::::::   0.9964720549980381
# run no..............   22
# adjusted r2 score ::::::::::   0.9964713195462885
# run no..............   23
# adjusted r2 score ::::::::::   0.9964756547676721
# run no..............   24
# adjusted r2 score ::::::::::   0.9964663825664787
# run no..............   25
# adjusted r2 score ::::::::::   0.9964689399483584
# run no..............   26
# adjusted r2 score ::::::::::   0.9964741831257276
# run no..............   27
# adjusted r2 score ::::::::::   0.9964707406124007
# run no..............   28
# adjusted r2 score ::::::::::   0.9964692494715229
# run no..............   29
# adjusted r2 score ::::::::::   0.9964716937559044
# run no..............   30
# adjusted r2 score ::::::::::   0.9964635276442897
# run no..............   31
# adjusted r2 score ::::::::::   0.9964725058401431
# run no..............   32
# adjusted r2 score ::::::::::   0.9972565181452275
# run no..............   33
# adjusted r2 score ::::::::::   0.9982367744150173
# run no..............   34
# adjusted r2 score ::::::::::   0.9987574463686172
# run no..............   35
# adjusted r2 score ::::::::::   0.9988110775426249
# run no..............   36
# adjusted r2 score ::::::::::   0.9992715879233097
# run no..............   37
# adjusted r2 score ::::::::::   0.9990688223153836
# run no..............   38
# adjusted r2 score ::::::::::   0.9987731660795017
# run no..............   39
# adjusted r2 score ::::::::::   0.9988739739069487
# run no..............   40
# adjusted r2 score ::::::::::   0.9988204914322358
# run no..............   41
# adjusted r2 score ::::::::::   0.9984834303663382
# run no..............   42
# adjusted r2 score ::::::::::   0.9982673584089358
# run no..............   43
# adjusted r2 score ::::::::::   0.9981334281578603
# run no..............   44
# adjusted r2 score ::::::::::   0.998157703094088
# run no..............   45
# adjusted r2 score ::::::::::   0.9980753484724056
# run no..............   46
# adjusted r2 score ::::::::::   0.9982860946041996
# run no..............   47
# adjusted r2 score ::::::::::   0.99829001110822
# run no..............   48
# adjusted r2 score ::::::::::   0.9982126235036582
# run no..............   49
# adjusted r2 score ::::::::::   0.998375860356513

# %%
feature_select_df = pd.DataFrame({"Top K features":feature_list,
                                  "MSE" : mse_list,
                                  "R2-score" : r2_list,
                                  "Adjusted R2" : adjr2_list}) 
feature_select_df.head()
# Out:
#    Top K features         MSE  R2-score  Adjusted R2
# 0               5  319.823811  0.644734     0.644538
# 1               6  319.893274  0.644657     0.644421
# 2               7  134.862927  0.850192     0.850076
# 3               8   83.004815  0.907797     0.907715
# 4               9   38.963282  0.956719     0.956676

# %%
feature_select_df.sort_values(by = 'Adjusted R2', ascending=False).head()
# Out:
#     Top K features       MSE  R2-score  Adjusted R2
# 31              36  0.653139  0.999274     0.999272
# 32              37  0.834858  0.999073     0.999069
# 34              39  1.009328  0.998879     0.998874
# 35              40  1.057151  0.998826     0.998820
# 30              35  1.066179  0.998816     0.998811

# %%
top_features = feature_importance_df['Feature'][:36].values
X_train_sel = X_train[top_features]
X_train_sel.columns
# Out:
# Index(['promotion_name_4', 'promotion_name_1', 'grocery_sqft',
#        'promotion_name_3', 'promotion_name_2', 'store_sqft', 'media_type_3',
#        'media_type_1', 'promotion_name_0', 'promotion_name_5', 'frozen_sqft',
#        'meat_sqft', 'store_type', 'media_type_0', 'store_state_3',
#        'media_type_2', 'store_city_3', 'store_city_2', 'store_state_2',
#        'store_state_1', 'store_city_1', 'video_store', 'store_city_4',
#        'florist', 'sales_country_0', 'sales_country_1', 'coffee_bar',
#        'store_city_0', 'prepared_food', 'salad_bar', 'store_state_0',
#        'profile_strength', 'total_children', 'education', 'avg. yearly_income',
#        'avg_cars_at home(approx)'],
#       dtype='object')

# %%
feature_select_df.to_csv('cac_dataset/feature_select_dataset.csv', sep='\t', encoding='utf-8', index=False, header=True)

# %%
import pickle

# %%
with open('models/model_pkl', 'wb') as files:
    pickle.dump(model_rf, files)

# %%
train, test = train_test_split(data, test_size=0.15, shuffle=True, random_state=42)
X_train = train.drop("cost", axis=1)
X_test = test.drop("cost", axis=1)
y_train = train["cost"]
y_test = test["cost"]
X_train, binary_encoder, scaler = preprocess_train(X_train)

# %%
with open('models/binary_encoder', 'wb') as files:
    pickle.dump(binary_encoder, files)
with open('models/scaler', 'wb') as files:
    pickle.dump(scaler, files)
